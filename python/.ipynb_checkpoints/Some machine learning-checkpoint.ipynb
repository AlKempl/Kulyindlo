# %%
import gensim
import re
import unicodedata
import pymystem3

# %%
f = open('stop_words.txt', 'r')
stop_words = []
for line in f:
    stop_words.append(line.strip())
print(len(stop_words))
print(stop_words)
# Out:
# 258
# ['а', 'без', 'более', 'бы', 'был', 'была', 'были', 'было', 'быть', 'в', 'вам', 'вас', 'весь', 'во', 'вот', 'все', 'всего', 'всех', 'вы', 'где', 'да', 'даже', 'для', 'доX', 'его', 'ее', 'если', 'есть', 'еще', 'же', 'за', 'здесь', 'и', 'из', 'или', 'им', 'их', 'к', 'как', 'ко', 'когда', 'кто', 'ли', 'либо', 'мне', 'может', 'мы', 'на', 'надо', 'наш', 'не', 'него', 'нее', 'нет', 'ни', 'них', 'но', 'ну', 'о', 'об', 'однако', 'он', 'она', 'они', 'оно', 'от', 'очень', 'по', 'под', 'при', 'с', 'со', 'так', 'также', 'такой', 'там', 'те', 'тем', 'то', 'того', 'тоже', 'той', 'только', 'том', 'ты', 'у', 'уже', 'хотя', 'чего', 'чей', 'чем', 'что', 'чтобы', 'чье', 'чья', 'эта', 'эти', 'это', 'я', 'и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'сказал', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'человек', 'чего', 'раз', 'тоже', 'себе', 'под', 'жизнь', 'будет', 'ж', 'тогда', 'кто', 'этот', 'говорил', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'кажется', 'сейчас', 'были', 'куда', 'зачем', 'сказать', 'всех', 'никогда', 'сегодня', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'сказала', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']

# %%
#f = open('verses.txt', 'r')
f = open('zaum.txt', 'r')
verses = []
preprocessed_verses = []
verse = ''
mystem = pymystem3.Mystem()
words_count = 0

for line in f:
    if line.startswith(u'*'):
        if verse != '':
            preprocessed_verse = []
            for word in mystem.analyze(verse):
                try:
                    lemma = word['analysis'][0]['lex']
                    #if not lemma in stop_words:
                    preprocessed_verse.append(lemma)
                    print(lemma)
                except:
                    continue
            if preprocessed_verse != []:
                verses.append(verse)
                preprocessed_verses.append(preprocessed_verse)
            words_count += len(preprocessed_verse)
            verse = ''
    else:
        verse += line

f = open('verses.txt', 'r')
for line in f:
    if line.startswith(u'*'):
        if verse != '':
            preprocessed_verse = []
            for word in mystem.analyze(verse):
                try:
                    lemma = word['analysis'][0]['lex']
                    if not lemma in stop_words:
                        preprocessed_verse.append(lemma)
                        print(lemma)
                except:
                    continue
            if preprocessed_verse != []:
                verses.append(verse)
                preprocessed_verses.append(preprocessed_verse)
            words_count += len(preprocessed_verse)
            verse = ''
    else:
        verse += line
print('Words count: ' + str(words_count))
# Out:
# читать
# крученыхиад
# феофан
# бук
# крученый
# звученый
# журченый
# ученый
# крученый
# реченый
# верченый
# ух
# марина
# дмитриевна
# про
# и
# пра
# и
# кро
# аз
# бук
# вести
# и
# добро
# листок
# перо
# евгений
# викторович
# сте
# и
# степь
# и
# стыд
# и
# разрушитель
# ватный
# стена
# и
# вечный
# жид
# а
# жизнь
# устраивать
# хитро
# добро
# добро
# и
# зло
# и
# злоба
# и
# добро
# листок
# перо
# заумь
# завымь
# безумить
# зумь
# безумить
# тамбовь
# любовь
# керз
# керз
# и
# эза
# рцы
# и
# графоман
# не
# графоман
# граф
# о
# манн
# геруф
# гарун
# эзра
# бездна
# ро
# добро
# поэт
# виртуоз
# курочкин
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# деньги
# у
# е
# у
# е
# а
# руб
# за
# бур
# есть
# у
# е
# съедать
# у
# е
# у
# ле
# а
# ле
# о
# е
# е
# е
# женя
# харитонов
# же
# ха
# то
# новый
# новый
# новый
# и
# тон
# ха
# ха
# ах
# ах
# жена
# я
# ха
# рита
# о
# но
# в
# тир
# о
# неж
# и
# и
# раж
# пылеу
# зылеу
# ылеу
# уля
# а
# грынга
# горынга
# зарынга
# зара
# не
# не
# курас
# курас
# поэт
# ю
# милый
# о
# и
# ю
# и
# о
# ю
# ми
# ю
# о
# ю
# рим
# и
# мир
# и
# оуэо
# эуо
# эра
# ряо
# ряо
# рэо
# ия
# гру
# меч
# кру
# ча
# он
# эх
# поморный
# лебедный
# ты
# меерный
# да
# бабный
# вот
# колючина
# не
# застригать
# он
# похучивать
# да
# пиич
# стилистика
# келья
# квартира
# корабль
# лететь
# во
# сон
# ноосфера
# зангезти
# зау
# за
# у
# за
# крен
# вирус
# и
# визг
# ты
# скрыбыр
# ты
# удар
# слово
# поддых
# и
# не
# слово
# день
# ги
# щипящий
# иго
# боль
# и
# больница
# реанимация
# мамочка
# мама
# не
# умирать
# папа
# держаться
# мама
# и
# папа
# не
# уходить
# не
# уходить
# не
# уходить
# взять
# мой
# сила
# сан
# ребенок
# прана
# он
# кобзарь
# озарь
# грандиозарь
# виртуозарь
# звень
# разом
# логос
# разум
# мрынь
# грынь
# или
# даже
# стыть
# стыть
# зау
# логос
# ребус
# женя
# шень
# вау
# логос
# мелос
# звень
# звень
# даже
# если
# это
# трень-брень
# даже
# если
# это
# дрянь
# хрень
# только
# все
# же
# это
# звень
# звень
# только
# все
# же
# это
# звень
# звень
# плоть
# путь
# плот
# плыть
# плоть
# пыл
# плоть
# жар
# плоть
# гроб
# прах
# дух
# дух
# путь
# дух
# путь
# и
# или
# ия
# лия
# ли
# или
# лия
# ия
# ли
# ия
# лия
# или
# и
# тася
# таить
# тот
# я
# я
# тот
# ты
# рот
# пьеса
# страсть
# страсть
# страсть
# страсть
# страсть
# занавес
# игра
# а
# вокзал
# глазков
# тет-а-тет
# а
# вон
# снова
# вонь
# бред
# колокол
# около
# руж
# ажур
# кока-кола
# броколли
# рюс
# и
# сюр
# и
# нема
# в
# помин
# тело
# и
# год
# я
# ныне
# ныне
# ныне
# дед
# диво
# лететь
# лебедь
# дебелый
# лететь
# как
# а
# жужжать
# шабаш
# полк
# как
# клоп
# аз
# за
# аз
# но
# коза
# а
# мама
# ведь
# дева
# лететь
# лебедь
# дебелый
# а
# жужжать
# не
# па
# па
# па
# пи
# пи
# пи
# ти
# ти
# ти
# не
# дыра
# бул
# щыл
# убещур
# скум
# вы
# со
# р
# л
# а
# не
# урарь
# хор
# кухарка
# а
# с
# ст
# ш
# щ
# ж
# з
# а
# жужжать
# лететь
# лебедь
# дебелый
# голос
# а
# лебеда
# дебелый
# лебеда
# а
# дебил
# да
# да
# да
# ад
# пирог
# о
# день
# не
# догорать
# о
# день
# не
# до
# давать
# давать
# либо
# ли
# бо
# давать
# боль
# стыд
# страх
# смрад
# госстрах
# икар
# рак
# человеческий
# жизнь
# тик
# так
# тик
# так
# тук
# тук
# тук
# тук
# садиться
# олеся
# мо
# ад
# тет-а-тет
# цена
# танец
# тенета
# мочь
# угомонить
# ока
# темь
# метко
# лежать
# тяжело
# дух
# худо
# ей-ей
# мат
# мат
# тат
# шум
# гам
# е
# маг
# му
# ш
# олеся
# село
# город
# дорогой
# э
# град
# гад
# даг
# дарг
# захотеться
# вынимать
# прямой
# полаживать
# сразу
# поступать
# вынимать
# класть
# вчера
# продавать
# душа
# черта
# причем
# выгодный
# цена
# замечать
# дефект
# гарантия
# вернуть
# короче
# главное
# улыбка
# диктор
# говорить
# кругом
# пи
# погода
# рассказывать
# николай
# малевич
# плюнуть
# чертыхнуться
# кубик
# рубик
# швырнуть
# казеть
# раскрасить
# черный
# собирать
# давно
# оксана
# жить
# успевать
# поскольку
# дело
# который
# сперва
# заканчивать
# жить
# сзади
# подходить
# прикрывать
# ладонь
# твой
# глаз
# слушать
# грустно
# виктор
# иван
# василий
# константин
# четыре
# год
# вокруг
# пятьдесят
# многу
# простой
# вещь
# приходиться
# объяснять
# встречаться
# глаз
# оба
# понимать
# необходимо
# повстречаться
# друг
# друг
# илья
# покрывать
# позор
# оказываться
# позор
# илья
# лицо
# позор
# узнавать
# губернатор
# проблема
# взять
# асфальт
# дорога
# ездить
# порше
# который
# накладной
# асфальт
# мужик
# идти
# конь
# поле
# конь
# внезапно
# говорить
# петь
# песня
# пусть
# секрет
# геннадий
# мысль
# блин
# существовать
# сантехник
# объяснять
# сын
# слово
# смысл
# поэма
# александр
# блок
# вопрос
# задание
# егэ
# вариант
# эскалибур
# двенадцать
# жопа
# карандаш
# параллельный
# прямой
# жить
# эвклидов
# мирок
# бегать
# пересекаться
# мир
# лобачевский
# тайком
# александра
# прочь
# пойти
# алтарь
# гость
# онемевать
# глядеть
# опустеть
# гроб
# шол
# спать
# какать
# вовсе
# любовь
# шол
# спать
# футбол
# какать
# расставаться
# пока
# известно
# встреча
# никто
# знать
# уничтожать
# планета
# негде
# жить
# уметь
# вещь
# юмор
# смотреть
# страшно
# бумага
# доставать
# чернила
# слеза
# подступать
# горло
# кончаться
# февраль
# современный
# искусство
# понимать
# сложно
# мочь
# нарисовать
# олег
# утренник
# школа
# глядеть
# плясать
# ребенок
# понимать
# счастие
# пора
# достаточно
# кот
# ложный
# скромность
# замечать
# гениальный
# ничто
# создавать
# занятый
# болеть
# секс
# бывать
# безопасный
# вздыхать
# мужчина
# топор
# отказ
# секс
# мочь
# сильно
# навредить
# украсть
# шапка
# мономах
# след
# шаинский
# вести
# первый
# алиби
# непрочно
# второй
# говорить
# мужчина
# слышаться
# секс
# долгий
# прямой
# какаято
# беда
# находить
# свалка
# улучшатель
# применять
# вокруг
# улучшать
# брат
# мать
# собака
# плохой
# ура
# внутри
# каждый
# космос
# значит
# каждый
# целое
# непригодный
# холодный
# пустой
# внутри
# предвидеть
# твой
# вопрос
# отвечать
# бедный
# злой
# трусливый
# слабый
# невезучий
# умный
# извинять
# нужно
# укреплять
# богема
# диктатор
# тотчас
# отборный
# тридцать
# офицер
# надевать
# шарф
# уходить
# запой
# ненавидеть
# долго
# принцип
# забывать
# почему
# ненавидеть
# собственно
# олег
# жениться
# завидовать
# любовь
# залет
# муж
# прекрасный
# море
# дорогой
# отпуск
# ехать
# гриб
# наслаждаться
# закат
# губа
# свой
# характер
# закалять
# преодоление
# преграда
# упорно
# циркуль
# рисовать
# квадрат
# входить
# дом
# пора
# осенний
# развивать
# тоска
# создавать
# семья
# обувь
# переться
# убивать
# дыхнуть
# ладонь
# украдкой
# брежнев
# разглаживать
# бровь
# вздергивать
# нос
# подумать
# чаушеска
# взасос
# искать
# существование
# смысыл
# внутри
# любовь
# искать
# понимать
# счастие
# завтра
# ща
# будить
# обсираться
# жрать
# хотеть
# аж
# мочь
# орать
# олег
# получаться
# ага
# здаров
# писать
# лор
# справка
# здаров
# писать
# ортопед
# хирург
# фсема
# чмок
# чят
# превед
# матроскин
# твой
# хозяин
# который
# объездить
# мир
# называть
# обычно
# мессир
# пусть
# карл
# клара
# постареть
# пронести
# сквозь
# год
# страсть
# смотреть
# друг
# друг
# украсть
# рубашка
# гладить
# шуба
# просить
# башка
# пелевин
# плутарх
# родной
# просто
# ангел
# арх
# боб
# марля
# таня
# высылать
# мячик
# обратно
# краснодарский
# край
# пометка
# вылавливать
# приходить
# бетховен
# почта
# странный
# коробок
# письмо
# дарить
# нужный
# ван
# гог
# подряд
# спасать
# становиться
# кричать
# рассердить
# мазай
# ежик
# пингвин
# зайя
# тошнить
# грамотей
# лицемерие
# ложь
# класть
# кафель
# ложа
# искать
# козерог
# попадаться
# овен
# причем
# овно
# морг
# прохладный
# чистый
# уют
# портить
# практикант
# блевать
# ненавидеть
# твой
# тэ
# девять
# писать
# любить
# писать
# выходить
# деньги
# сука
# слать
# ворона
# вместо
# сыр
# господь
# посылать
# тирамис
# озадачивать
# лиса
# мяч
# резиновый
# эскадра
# нестись
# гонимый
# нева
# страшный
# облик
# таня
# вой
# лежать
# маленький
# коли
# карман
# тридцать
# желудь
# богато
# свет
# воспринимать
# равный
# существо
# настолько
# сука
# превосходить
# статья
# самый
# минута
# бог
# смотреть
# пристально
# думать
# сначала
# тапок
# сначала
# дихлофос
# поэт
# мочь
# счастливый
# сразу
# поэт
# несчастный
# снова
# поэт
# жить
# хлеб
# непомыть
# плита
# спрашивать
# андрей
# сразу
# умирать
# крайний
# мера
# купить
# диван
# купить
# продукт
# купить
# киоск
# сигарета
# купить
# бухнуть
# приходить
# квартира
# сидеть
# курить
# бухать
# олег
# маньяк
# татуировщик
# уклон
# национализм
# татуировать
# нерусский
# палех
# гжель
# хохлома
# мужчина
# вовсе
# загадка
# суть
# простой
# пирожок
# пирожок
# штука
# объяснять
# рыдать
# кровавый
# слеза
# выходить
# замуж
# петр
# приходить
# ночь
# эсэмэск
# што
# петр
# олег
# хотеть
# жить
# ижевск
# милый
# сэн
# тропэ
# зарплата
# ехать
# туда
# двадцать
# пять
# секунда
# последний
# идиот
# тридцать
# год
# стоять
# хвост
# постепенно
# продвигаться
# первый
# идиот
# хотеть
# становиться
# пророк
# гибель
# предрекать
# б
# верить
# смеяться
# говорить
# рано
# думать
# становиться
# взрослый
# далее
# проходить
# становиться
# взрослый
# семен
# успевать
# электричка
# сломать
# нос
# сидеть
# понимать
# мочь
# везучий
# утро
# ехать
# работа
# работа
# снова
# ехать
# работа
# поскольку
# следующий
# день
# увы
# раб
# свой
# желание
# подневольный
# хотеть
# еда
# приходиться
# покушать
# хотеть
# поспать
# приходиться
# поспать
# слово
# хуй
# галерка
# вставать
# партер
# попрятать
# веер
# замирать
# игорь
# гобой
# ужас
# нагнетать
# фотоаппарат
# кончаться
# заряд
# обязательно
# навстречу
# бежать
# нудистка
# лось
# катиться
# колобок
# лес
# петь
# песня
# уходить
# дело
# замечать
# рот
# проехать
# гавно
# любить
# подумать
# пушкин
# включать
# планшет
# открывать
# блокнот
# любить
# любовь
# мочь
# загуглить
# вроде
# боян
# сходиться
# фома
# станиславский
# друг
# против
# друг
# становиться
# рост
# олимпиец
# состязаться
# переневерять
# мочь
# сильный
# страсть
# спрашивать
# мастер
# олег
# немедленно
# отвечать
# заползщий
# ухо
# муравей
# оксана
# нравиться
# фламенко
# олег
# классика
# джаз
# вдвоем
# сцена
# петь
# лагерь
# мусор
# Words count: 1257

# %%
model = gensim.models.Word2Vec(preprocessed_verses, size=150, window=15, min_count=1)
model.train(preprocessed_verses, total_examples=len(verses), epochs=15)
# Out:
# (17066, 18855)

# %%
len(model.wv.vocab)
# Out:
# 843

# %%
model.wv.vocab
# Out:
# {'читать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916cf8>,
#  'крученыхиад': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916d30>,
#  'феофан': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916c18>,
#  'бук': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916c88>,
#  'крученый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916cc0>,
#  'звученый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916c50>,
#  'журченый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916b70>,
#  'ученый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916dd8>,
#  'реченый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916e10>,
#  'верченый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916eb8>,
#  'ух': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916e48>,
#  'марина': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916e80>,
#  'дмитриевна': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916ef0>,
#  'про': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916f28>,
#  'и': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916f98>,
#  'пра': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916f60>,
#  'кро': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916a20>,
#  'аз': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916ac8>,
#  'вести': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916a58>,
#  'добро': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916a90>,
#  'листок': <gensim.models.keyedvectors.Vocab at 0x7ff4b99169e8>,
#  'перо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916860>,
#  'евгений': <gensim.models.keyedvectors.Vocab at 0x7ff4b99168d0>,
#  'викторович': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916898>,
#  'сте': <gensim.models.keyedvectors.Vocab at 0x7ff4b99166a0>,
#  'степь': <gensim.models.keyedvectors.Vocab at 0x7ff4b99167f0>,
#  'стыд': <gensim.models.keyedvectors.Vocab at 0x7ff4b99165c0>,
#  'разрушитель': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916588>,
#  'ватный': <gensim.models.keyedvectors.Vocab at 0x7ff4b99165f8>,
#  'стена': <gensim.models.keyedvectors.Vocab at 0x7ff4b9916518>,
#  'вечный': <gensim.models.keyedvectors.Vocab at 0x7ff4b99166d8>,
#  'жид': <gensim.models.keyedvectors.Vocab at 0x7ff4e1395940>,
#  'а': <gensim.models.keyedvectors.Vocab at 0x7ff4e1395908>,
#  'жизнь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d748>,
#  'устраивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d7b8>,
#  'хитро': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d780>,
#  'зло': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d208>,
#  'злоба': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d240>,
#  'заумь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d048>,
#  'завымь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d0f0>,
#  'безумить': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d080>,
#  'зумь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d0b8>,
#  'тамбовь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d128>,
#  'любовь': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d160>,
#  'керз': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d1d0>,
#  'эза': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d198>,
#  'рцы': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d278>,
#  'графоман': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d358>,
#  'не': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d390>,
#  'граф': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d438>,
#  'о': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d3c8>,
#  'манн': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d400>,
#  'геруф': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d470>,
#  'гарун': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d4a8>,
#  'эзра': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d550>,
#  'бездна': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d4e0>,
#  'ро': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d518>,
#  'поэт': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d2b0>,
#  'виртуоз': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d320>,
#  'курочкин': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d2e8>,
#  'ко': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d588>,
#  'деньги': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d5f8>,
#  'у': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d668>,
#  'е': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d630>,
#  'руб': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d5c0>,
#  'за': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d6a0>,
#  'бур': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d710>,
#  'есть': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d6d8>,
#  'съедать': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d7f0>,
#  'ле': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d828>,
#  'женя': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d898>,
#  'харитонов': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d908>,
#  'же': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d978>,
#  'ха': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d940>,
#  'то': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d8d0>,
#  'новый': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d860>,
#  'тон': <gensim.models.keyedvectors.Vocab at 0x7ff4b992d9b0>,
#  'ах': <gensim.models.keyedvectors.Vocab at 0x7ff4b992db00>,
#  'жена': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dc18>,
#  'я': <gensim.models.keyedvectors.Vocab at 0x7ff4b992da90>,
#  'рита': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dc50>,
#  'но': <gensim.models.keyedvectors.Vocab at 0x7ff4b992df98>,
#  'в': <gensim.models.keyedvectors.Vocab at 0x7ff4b992de80>,
#  'тир': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dc88>,
#  'неж': <gensim.models.keyedvectors.Vocab at 0x7ff4b992de10>,
#  'раж': <gensim.models.keyedvectors.Vocab at 0x7ff4b992df60>,
#  'пылеу': <gensim.models.keyedvectors.Vocab at 0x7ff4b992db70>,
#  'зылеу': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dd68>,
#  'ылеу': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dfd0>,
#  'уля': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dcc0>,
#  'грынга': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dcf8>,
#  'горынга': <gensim.models.keyedvectors.Vocab at 0x7ff4b992de48>,
#  'зарынга': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dba8>,
#  'зара': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dda0>,
#  'курас': <gensim.models.keyedvectors.Vocab at 0x7ff4b992db38>,
#  'ю': <gensim.models.keyedvectors.Vocab at 0x7ff4b992def0>,
#  'милый': <gensim.models.keyedvectors.Vocab at 0x7ff4b992deb8>,
#  'ми': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dbe0>,
#  'рим': <gensim.models.keyedvectors.Vocab at 0x7ff4b992dd30>,
#  'мир': <gensim.models.keyedvectors.Vocab at 0x7ff4b992ddd8>,
#  'оуэо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926048>,
#  'эуо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926080>,
#  'эра': <gensim.models.keyedvectors.Vocab at 0x7ff4b99260b8>,
#  'ряо': <gensim.models.keyedvectors.Vocab at 0x7ff4b99260f0>,
#  'рэо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926128>,
#  'ия': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926160>,
#  'гру': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926198>,
#  'меч': <gensim.models.keyedvectors.Vocab at 0x7ff4b99261d0>,
#  'кру': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926208>,
#  'ча': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926240>,
#  'он': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926278>,
#  'эх': <gensim.models.keyedvectors.Vocab at 0x7ff4b99262b0>,
#  'поморный': <gensim.models.keyedvectors.Vocab at 0x7ff4b99262e8>,
#  'лебедный': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926320>,
#  'ты': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926358>,
#  'меерный': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926390>,
#  'да': <gensim.models.keyedvectors.Vocab at 0x7ff4b99263c8>,
#  'бабный': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926400>,
#  'вот': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926438>,
#  'колючина': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926470>,
#  'застригать': <gensim.models.keyedvectors.Vocab at 0x7ff4b99264a8>,
#  'похучивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b99264e0>,
#  'пиич': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926518>,
#  'стилистика': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926550>,
#  'келья': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926588>,
#  'квартира': <gensim.models.keyedvectors.Vocab at 0x7ff4b99265c0>,
#  'корабль': <gensim.models.keyedvectors.Vocab at 0x7ff4b99265f8>,
#  'лететь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926630>,
#  'во': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926668>,
#  'сон': <gensim.models.keyedvectors.Vocab at 0x7ff4b99266a0>,
#  'ноосфера': <gensim.models.keyedvectors.Vocab at 0x7ff4b99266d8>,
#  'зангезти': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926710>,
#  'зау': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926748>,
#  'крен': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926780>,
#  'вирус': <gensim.models.keyedvectors.Vocab at 0x7ff4b99267b8>,
#  'визг': <gensim.models.keyedvectors.Vocab at 0x7ff4b99267f0>,
#  'скрыбыр': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926828>,
#  'удар': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926860>,
#  'слово': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926898>,
#  'поддых': <gensim.models.keyedvectors.Vocab at 0x7ff4b99268d0>,
#  'день': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926908>,
#  'ги': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926940>,
#  'щипящий': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926978>,
#  'иго': <gensim.models.keyedvectors.Vocab at 0x7ff4b99269b0>,
#  'боль': <gensim.models.keyedvectors.Vocab at 0x7ff4b99269e8>,
#  'больница': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926a20>,
#  'реанимация': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926a58>,
#  'мамочка': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926a90>,
#  'мама': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926ac8>,
#  'умирать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926b00>,
#  'папа': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926b38>,
#  'держаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926b70>,
#  'уходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926ba8>,
#  'взять': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926be0>,
#  'мой': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926c18>,
#  'сила': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926c50>,
#  'сан': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926c88>,
#  'ребенок': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926cc0>,
#  'прана': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926cf8>,
#  'кобзарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926d30>,
#  'озарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926d68>,
#  'грандиозарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926da0>,
#  'виртуозарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926dd8>,
#  'звень': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926e10>,
#  'разом': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926e48>,
#  'логос': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926e80>,
#  'разум': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926eb8>,
#  'мрынь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926ef0>,
#  'грынь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926f28>,
#  'или': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926f60>,
#  'даже': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926f98>,
#  'стыть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9926fd0>,
#  'ребус': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e10f0>,
#  'шень': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1048>,
#  'вау': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e10b8>,
#  'мелос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1080>,
#  'если': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1128>,
#  'это': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1160>,
#  'трень-брень': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1198>,
#  'дрянь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e11d0>,
#  'хрень': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1208>,
#  'только': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1240>,
#  'все': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1278>,
#  'плоть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e12b0>,
#  'путь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e12e8>,
#  'плот': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1320>,
#  'плыть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1358>,
#  'пыл': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1390>,
#  'жар': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e13c8>,
#  'гроб': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1400>,
#  'прах': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1438>,
#  'дух': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1470>,
#  'лия': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e14a8>,
#  'ли': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e14e0>,
#  'тася': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1518>,
#  'таить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1550>,
#  'тот': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1588>,
#  'рот': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e15c0>,
#  'пьеса': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e15f8>,
#  'страсть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1630>,
#  'занавес': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1668>,
#  'игра': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e16a0>,
#  'вокзал': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e16d8>,
#  'глазков': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1710>,
#  'тет-а-тет': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1748>,
#  'вон': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1780>,
#  'снова': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e17b8>,
#  'вонь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e17f0>,
#  'бред': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1828>,
#  'колокол': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1860>,
#  'около': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1898>,
#  'руж': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e18d0>,
#  'ажур': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1908>,
#  'кока-кола': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1940>,
#  'броколли': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1978>,
#  'рюс': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e19b0>,
#  'сюр': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e19e8>,
#  'нема': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1a20>,
#  'помин': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1a58>,
#  'тело': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1a90>,
#  'год': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1ac8>,
#  'ныне': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1b00>,
#  'дед': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1b38>,
#  'диво': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1b70>,
#  'лебедь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1ba8>,
#  'дебелый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1be0>,
#  'как': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1c18>,
#  'жужжать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1c50>,
#  'шабаш': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1c88>,
#  'полк': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1cc0>,
#  'клоп': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1cf8>,
#  'коза': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1d30>,
#  'ведь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1d68>,
#  'дева': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1da0>,
#  'па': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1dd8>,
#  'пи': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1e10>,
#  'ти': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1e48>,
#  'дыра': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1e80>,
#  'бул': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1eb8>,
#  'щыл': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1ef0>,
#  'убещур': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1f28>,
#  'скум': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1f60>,
#  'вы': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1f98>,
#  'со': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e1fd0>,
#  'р': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3048>,
#  'л': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3080>,
#  'урарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e30b8>,
#  'хор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e30f0>,
#  'кухарка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3128>,
#  'с': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3160>,
#  'ст': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3198>,
#  'ш': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e31d0>,
#  'щ': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3208>,
#  'ж': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3240>,
#  'з': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3278>,
#  'голос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e32b0>,
#  'лебеда': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e32e8>,
#  'дебил': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3320>,
#  'ад': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3358>,
#  'пирог': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3390>,
#  'догорать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e33c8>,
#  'до': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3400>,
#  'давать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3438>,
#  'либо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3470>,
#  'бо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e34a8>,
#  'страх': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e34e0>,
#  'смрад': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3518>,
#  'госстрах': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3588>,
#  'икар': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e35c0>,
#  'рак': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e35f8>,
#  'человеческий': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3630>,
#  'тик': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3668>,
#  'так': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e36a0>,
#  'тук': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e36d8>,
#  'садиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3710>,
#  'олеся': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3748>,
#  'мо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3780>,
#  'цена': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e37b8>,
#  'танец': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e37f0>,
#  'тенета': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3828>,
#  'мочь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3860>,
#  'угомонить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3898>,
#  'ока': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e38d0>,
#  'темь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3908>,
#  'метко': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3940>,
#  'лежать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3978>,
#  'тяжело': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e39b0>,
#  'худо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e39e8>,
#  'ей-ей': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3a20>,
#  'мат': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3a58>,
#  'тат': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3a90>,
#  'шум': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3ac8>,
#  'гам': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3b00>,
#  'маг': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3b38>,
#  'му': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3b70>,
#  'село': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3ba8>,
#  'город': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3be0>,
#  'дорогой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3c18>,
#  'э': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3c50>,
#  'град': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3c88>,
#  'гад': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3cc0>,
#  'даг': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3cf8>,
#  'дарг': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3d30>,
#  'захотеться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3d68>,
#  'вынимать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3da0>,
#  'прямой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3dd8>,
#  'полаживать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3e10>,
#  'сразу': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3e48>,
#  'поступать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3e80>,
#  'класть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3eb8>,
#  'вчера': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3ef0>,
#  'продавать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3f28>,
#  'душа': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3f60>,
#  'черта': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3f98>,
#  'причем': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e3fd0>,
#  'выгодный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4048>,
#  'замечать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4080>,
#  'дефект': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e40b8>,
#  'гарантия': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e40f0>,
#  'вернуть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4128>,
#  'короче': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4160>,
#  'главное': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4198>,
#  'улыбка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e41d0>,
#  'диктор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4208>,
#  'говорить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4240>,
#  'кругом': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4278>,
#  'погода': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e42b0>,
#  'рассказывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e42e8>,
#  'николай': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4320>,
#  'малевич': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4358>,
#  'плюнуть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4390>,
#  'чертыхнуться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e43c8>,
#  'кубик': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4400>,
#  'рубик': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4438>,
#  'швырнуть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4470>,
#  'казеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e44a8>,
#  'раскрасить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e44e0>,
#  'черный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4518>,
#  'собирать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4550>,
#  'давно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4588>,
#  'оксана': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e45c0>,
#  'жить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e45f8>,
#  'успевать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4630>,
#  'поскольку': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4668>,
#  'дело': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e46a0>,
#  'который': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e46d8>,
#  'сперва': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4710>,
#  'заканчивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4748>,
#  'сзади': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4780>,
#  'подходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e47b8>,
#  'прикрывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e47f0>,
#  'ладонь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4828>,
#  'твой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4860>,
#  'глаз': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4898>,
#  'слушать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e48d0>,
#  'грустно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4908>,
#  'виктор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4940>,
#  'иван': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4978>,
#  'василий': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e49b0>,
#  'константин': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e49e8>,
#  'четыре': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4a20>,
#  'вокруг': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4a58>,
#  'пятьдесят': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4a90>,
#  'многу': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4ac8>,
#  'простой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4b00>,
#  'вещь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4b38>,
#  'приходиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4b70>,
#  'объяснять': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4ba8>,
#  'встречаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4be0>,
#  'оба': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4c18>,
#  'понимать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4c50>,
#  'необходимо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4c88>,
#  'повстречаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4cc0>,
#  'друг': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4cf8>,
#  'илья': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4d30>,
#  'покрывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4d68>,
#  'позор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4da0>,
#  'оказываться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4dd8>,
#  'лицо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4e10>,
#  'узнавать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4e48>,
#  'губернатор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4e80>,
#  'проблема': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4eb8>,
#  'асфальт': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4ef0>,
#  'дорога': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4f28>,
#  'ездить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4f60>,
#  'порше': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4f98>,
#  'накладной': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e4fd0>,
#  'мужик': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8048>,
#  'идти': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8080>,
#  'конь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e80b8>,
#  'поле': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e80f0>,
#  'внезапно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8128>,
#  'петь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8160>,
#  'песня': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8198>,
#  'пусть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e81d0>,
#  'секрет': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8208>,
#  'геннадий': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8240>,
#  'мысль': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8278>,
#  'блин': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e82b0>,
#  'существовать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e82e8>,
#  'сантехник': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8320>,
#  'сын': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8358>,
#  'смысл': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8390>,
#  'поэма': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e83c8>,
#  'александр': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8400>,
#  'блок': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8438>,
#  'вопрос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8470>,
#  'задание': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e84a8>,
#  'егэ': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e84e0>,
#  'вариант': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8518>,
#  'эскалибур': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8550>,
#  'двенадцать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8588>,
#  'жопа': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e85c0>,
#  'карандаш': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e85f8>,
#  'параллельный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8630>,
#  'эвклидов': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8668>,
#  'мирок': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e86a0>,
#  'бегать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e86d8>,
#  'пересекаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8710>,
#  'лобачевский': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8748>,
#  'тайком': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8780>,
#  'александра': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e87b8>,
#  'прочь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e87f0>,
#  'пойти': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8828>,
#  'алтарь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8860>,
#  'гость': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8898>,
#  'онемевать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e88d0>,
#  'глядеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8908>,
#  'опустеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8940>,
#  'шол': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8978>,
#  'спать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e89b0>,
#  'какать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e89e8>,
#  'вовсе': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8a20>,
#  'футбол': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8a58>,
#  'расставаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8a90>,
#  'пока': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8ac8>,
#  'известно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8b00>,
#  'встреча': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8b38>,
#  'никто': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8b70>,
#  'знать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8ba8>,
#  'уничтожать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8be0>,
#  'планета': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8c18>,
#  'негде': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8c50>,
#  'уметь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8c88>,
#  'юмор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8cc0>,
#  'смотреть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8cf8>,
#  'страшно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8d30>,
#  'бумага': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8d68>,
#  'доставать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8da0>,
#  'чернила': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8dd8>,
#  'слеза': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8e10>,
#  'подступать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8e48>,
#  'горло': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8e80>,
#  'кончаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8eb8>,
#  'февраль': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8ef0>,
#  'современный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8f28>,
#  'искусство': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8f60>,
#  'сложно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8f98>,
#  'нарисовать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98e8fd0>,
#  'олег': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec048>,
#  'утренник': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec080>,
#  'школа': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec0b8>,
#  'плясать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec0f0>,
#  'счастие': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec128>,
#  'пора': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec160>,
#  'достаточно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec198>,
#  'кот': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec1d0>,
#  'ложный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec208>,
#  'скромность': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec240>,
#  'гениальный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec278>,
#  'ничто': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec2b0>,
#  'создавать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec2e8>,
#  'занятый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec320>,
#  'болеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec358>,
#  'секс': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec390>,
#  'бывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec3c8>,
#  'безопасный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec400>,
#  'вздыхать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec438>,
#  'мужчина': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec470>,
#  'топор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec4a8>,
#  'отказ': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec4e0>,
#  'сильно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec518>,
#  'навредить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec550>,
#  'украсть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec588>,
#  'шапка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec5c0>,
#  'мономах': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec5f8>,
#  'след': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec630>,
#  'шаинский': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec668>,
#  'первый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec6a0>,
#  'алиби': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec6d8>,
#  'непрочно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec710>,
#  'второй': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec748>,
#  'слышаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec780>,
#  'долгий': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec7b8>,
#  'какаято': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec7f0>,
#  'беда': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec828>,
#  'находить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec860>,
#  'свалка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec898>,
#  'улучшатель': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec8d0>,
#  'применять': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec908>,
#  'улучшать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec940>,
#  'брат': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec978>,
#  'мать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec9b0>,
#  'собака': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ec9e8>,
#  'плохой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eca20>,
#  'ура': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eca58>,
#  'внутри': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eca90>,
#  'каждый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecac8>,
#  'космос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecb00>,
#  'значит': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecb38>,
#  'целое': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecb70>,
#  'непригодный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecba8>,
#  'холодный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecbe0>,
#  'пустой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecc18>,
#  'предвидеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecc50>,
#  'отвечать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecc88>,
#  'бедный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eccc0>,
#  'злой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eccf8>,
#  'трусливый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecd30>,
#  'слабый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecd68>,
#  'невезучий': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecda0>,
#  'умный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecdd8>,
#  'извинять': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ece10>,
#  'нужно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ece48>,
#  'укреплять': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ece80>,
#  'богема': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eceb8>,
#  'диктатор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecef0>,
#  'тотчас': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecf28>,
#  'отборный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecf60>,
#  'тридцать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecf98>,
#  'офицер': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ecfd0>,
#  'надевать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef048>,
#  'шарф': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef080>,
#  'запой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef0b8>,
#  'ненавидеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef0f0>,
#  'долго': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef128>,
#  'принцип': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef160>,
#  'забывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef198>,
#  'почему': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef1d0>,
#  'собственно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef208>,
#  'жениться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef240>,
#  'завидовать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef278>,
#  'залет': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef2b0>,
#  'муж': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef2e8>,
#  'прекрасный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef320>,
#  'море': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef358>,
#  'отпуск': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef390>,
#  'ехать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef3c8>,
#  'гриб': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef400>,
#  'наслаждаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef438>,
#  'закат': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef470>,
#  'губа': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef4a8>,
#  'свой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef4e0>,
#  'характер': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef518>,
#  'закалять': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef550>,
#  'преодоление': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef588>,
#  'преграда': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef5c0>,
#  'упорно': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef5f8>,
#  'циркуль': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef630>,
#  'рисовать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef668>,
#  'квадрат': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef6a0>,
#  'входить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef6d8>,
#  'дом': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef710>,
#  'осенний': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef748>,
#  'развивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef780>,
#  'тоска': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef7b8>,
#  'семья': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef7f0>,
#  'обувь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef828>,
#  'переться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef860>,
#  'убивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef898>,
#  'дыхнуть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef8d0>,
#  'украдкой': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef908>,
#  'брежнев': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef940>,
#  'разглаживать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef978>,
#  'бровь': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef9b0>,
#  'вздергивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98ef9e8>,
#  'нос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efa20>,
#  'подумать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efa58>,
#  'чаушеска': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efa90>,
#  'взасос': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efac8>,
#  'искать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efb00>,
#  'существование': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efb38>,
#  'смысыл': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efb70>,
#  'завтра': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efba8>,
#  'ща': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efbe0>,
#  'будить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efc18>,
#  'обсираться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efc50>,
#  'жрать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efc88>,
#  'хотеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efcc0>,
#  'аж': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efcf8>,
#  'орать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efd30>,
#  'получаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efd68>,
#  'ага': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efda0>,
#  'здаров': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efdd8>,
#  'писать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efe10>,
#  'лор': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efe48>,
#  'справка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efe80>,
#  'ортопед': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efeb8>,
#  'хирург': <gensim.models.keyedvectors.Vocab at 0x7ff4b98efef0>,
#  'фсема': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eff28>,
#  'чмок': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eff60>,
#  'чят': <gensim.models.keyedvectors.Vocab at 0x7ff4b98eff98>,
#  'превед': <gensim.models.keyedvectors.Vocab at 0x7ff4b98effd0>,
#  'матроскин': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873048>,
#  'хозяин': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873080>,
#  'объездить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98730b8>,
#  'называть': <gensim.models.keyedvectors.Vocab at 0x7ff4b98730f0>,
#  'обычно': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873128>,
#  'мессир': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873160>,
#  'карл': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873198>,
#  'клара': <gensim.models.keyedvectors.Vocab at 0x7ff4b98731d0>,
#  'постареть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873208>,
#  'пронести': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873240>,
#  'сквозь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873278>,
#  'рубашка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98732b0>,
#  'гладить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98732e8>,
#  'шуба': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873320>,
#  'просить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873358>,
#  'башка': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873390>,
#  'пелевин': <gensim.models.keyedvectors.Vocab at 0x7ff4b98733c8>,
#  'плутарх': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873400>,
#  'родной': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873438>,
#  'просто': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873470>,
#  'ангел': <gensim.models.keyedvectors.Vocab at 0x7ff4b98734a8>,
#  'арх': <gensim.models.keyedvectors.Vocab at 0x7ff4b98734e0>,
#  'боб': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873518>,
#  'марля': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873550>,
#  'таня': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873588>,
#  'высылать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98735c0>,
#  'мячик': <gensim.models.keyedvectors.Vocab at 0x7ff4b98735f8>,
#  'обратно': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873630>,
#  'краснодарский': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873668>,
#  'край': <gensim.models.keyedvectors.Vocab at 0x7ff4b98736a0>,
#  'пометка': <gensim.models.keyedvectors.Vocab at 0x7ff4b98736d8>,
#  'вылавливать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873710>,
#  'приходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873748>,
#  'бетховен': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873780>,
#  'почта': <gensim.models.keyedvectors.Vocab at 0x7ff4b98737b8>,
#  'странный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98737f0>,
#  'коробок': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873828>,
#  'письмо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873860>,
#  'дарить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873898>,
#  'нужный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98738d0>,
#  'ван': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873908>,
#  'гог': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873940>,
#  'подряд': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873978>,
#  'спасать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98739b0>,
#  'становиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b98739e8>,
#  'кричать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873a20>,
#  'рассердить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873a58>,
#  'мазай': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873a90>,
#  'ежик': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873ac8>,
#  'пингвин': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873b00>,
#  'зайя': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873b38>,
#  'тошнить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873b70>,
#  'грамотей': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873ba8>,
#  'лицемерие': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873be0>,
#  'ложь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873c18>,
#  'кафель': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873c50>,
#  'ложа': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873c88>,
#  'козерог': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873cc0>,
#  'попадаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873cf8>,
#  'овен': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873d30>,
#  'овно': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873d68>,
#  'морг': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873da0>,
#  'прохладный': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873dd8>,
#  'чистый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873e10>,
#  'уют': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873e48>,
#  'портить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873e80>,
#  'практикант': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873eb8>,
#  'блевать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873ef0>,
#  'тэ': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873f28>,
#  'девять': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873f60>,
#  'любить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873f98>,
#  'выходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9873fd0>,
#  'сука': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876048>,
#  'слать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876080>,
#  'ворона': <gensim.models.keyedvectors.Vocab at 0x7ff4b98760b8>,
#  'вместо': <gensim.models.keyedvectors.Vocab at 0x7ff4b98760f0>,
#  'сыр': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876128>,
#  'господь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876160>,
#  'посылать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876198>,
#  'тирамис': <gensim.models.keyedvectors.Vocab at 0x7ff4b98761d0>,
#  'озадачивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876208>,
#  'лиса': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876240>,
#  'мяч': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876278>,
#  'резиновый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98762b0>,
#  'эскадра': <gensim.models.keyedvectors.Vocab at 0x7ff4b98762e8>,
#  'нестись': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876320>,
#  'гонимый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876358>,
#  'нева': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876390>,
#  'страшный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98763c8>,
#  'облик': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876400>,
#  'вой': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876438>,
#  'маленький': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876470>,
#  'коли': <gensim.models.keyedvectors.Vocab at 0x7ff4b98764a8>,
#  'карман': <gensim.models.keyedvectors.Vocab at 0x7ff4b98764e0>,
#  'желудь': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876518>,
#  'богато': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876550>,
#  'свет': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876588>,
#  'воспринимать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98765c0>,
#  'равный': <gensim.models.keyedvectors.Vocab at 0x7ff4b98765f8>,
#  'существо': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876630>,
#  'настолько': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876668>,
#  'превосходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b98766a0>,
#  'статья': <gensim.models.keyedvectors.Vocab at 0x7ff4b98766d8>,
#  'самый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876710>,
#  'минута': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876748>,
#  'бог': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876780>,
#  'пристально': <gensim.models.keyedvectors.Vocab at 0x7ff4b98767b8>,
#  'думать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98767f0>,
#  'сначала': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876828>,
#  'тапок': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876860>,
#  'дихлофос': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876898>,
#  'счастливый': <gensim.models.keyedvectors.Vocab at 0x7ff4b98768d0>,
#  'несчастный': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876908>,
#  'хлеб': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876940>,
#  'непомыть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876978>,
#  'плита': <gensim.models.keyedvectors.Vocab at 0x7ff4b98769b0>,
#  'спрашивать': <gensim.models.keyedvectors.Vocab at 0x7ff4b98769e8>,
#  'андрей': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876a20>,
#  'крайний': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876a58>,
#  'мера': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876a90>,
#  'купить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876ac8>,
#  'диван': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876b00>,
#  'продукт': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876b38>,
#  'киоск': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876b70>,
#  'сигарета': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876ba8>,
#  'бухнуть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876be0>,
#  'сидеть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876c18>,
#  'курить': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876c50>,
#  'бухать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876c88>,
#  'маньяк': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876cc0>,
#  'татуировщик': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876cf8>,
#  'уклон': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876d30>,
#  'национализм': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876d68>,
#  'татуировать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876da0>,
#  'нерусский': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876dd8>,
#  'палех': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876e10>,
#  'гжель': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876e48>,
#  'хохлома': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876e80>,
#  'загадка': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876eb8>,
#  'суть': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876ef0>,
#  'пирожок': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876f28>,
#  'штука': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876f60>,
#  'рыдать': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876f98>,
#  'кровавый': <gensim.models.keyedvectors.Vocab at 0x7ff4b9876fd0>,
#  'замуж': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a048>,
#  'петр': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a080>,
#  'ночь': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a0b8>,
#  'эсэмэск': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a0f0>,
#  'што': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a128>,
#  'ижевск': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a160>,
#  'сэн': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a198>,
#  'тропэ': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a1d0>,
#  'зарплата': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a208>,
#  'туда': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a240>,
#  'двадцать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a278>,
#  'пять': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a2b0>,
#  'секунда': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a2e8>,
#  'последний': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a320>,
#  'идиот': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a358>,
#  'стоять': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a390>,
#  'хвост': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a3c8>,
#  'постепенно': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a400>,
#  'продвигаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a438>,
#  'пророк': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a470>,
#  'гибель': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a4a8>,
#  'предрекать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a4e0>,
#  'б': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a518>,
#  'верить': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a550>,
#  'смеяться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a588>,
#  'рано': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a5c0>,
#  'взрослый': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a5f8>,
#  'далее': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a630>,
#  'проходить': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a668>,
#  'семен': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a6a0>,
#  'электричка': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a6d8>,
#  'сломать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a710>,
#  'везучий': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a748>,
#  'утро': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a780>,
#  'работа': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a7b8>,
#  'следующий': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a7f0>,
#  'увы': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a828>,
#  'раб': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a860>,
#  'желание': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a898>,
#  'подневольный': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a8d0>,
#  'еда': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a908>,
#  'покушать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a940>,
#  'поспать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a978>,
#  'хуй': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a9b0>,
#  'галерка': <gensim.models.keyedvectors.Vocab at 0x7ff4b987a9e8>,
#  'вставать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aa20>,
#  'партер': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aa58>,
#  'попрятать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aa90>,
#  'веер': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aac8>,
#  'замирать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ab00>,
#  'игорь': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ab38>,
#  'гобой': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ab70>,
#  'ужас': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aba8>,
#  'нагнетать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987abe0>,
#  'фотоаппарат': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ac18>,
#  'заряд': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ac50>,
#  'обязательно': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ac88>,
#  'навстречу': <gensim.models.keyedvectors.Vocab at 0x7ff4b987acc0>,
#  'бежать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987acf8>,
#  'нудистка': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ad30>,
#  'лось': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ad68>,
#  'катиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ada0>,
#  'колобок': <gensim.models.keyedvectors.Vocab at 0x7ff4b987add8>,
#  'лес': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ae10>,
#  'проехать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ae48>,
#  'гавно': <gensim.models.keyedvectors.Vocab at 0x7ff4b987ae80>,
#  'пушкин': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aeb8>,
#  'включать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987aef0>,
#  'планшет': <gensim.models.keyedvectors.Vocab at 0x7ff4b987af28>,
#  'открывать': <gensim.models.keyedvectors.Vocab at 0x7ff4b987af60>,
#  'блокнот': <gensim.models.keyedvectors.Vocab at 0x7ff4b987af98>,
#  'загуглить': <gensim.models.keyedvectors.Vocab at 0x7ff4b987afd0>,
#  'вроде': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d048>,
#  'боян': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d080>,
#  'сходиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d0b8>,
#  'фома': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d0f0>,
#  'станиславский': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d128>,
#  'против': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d160>,
#  'рост': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d198>,
#  'олимпиец': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d1d0>,
#  'состязаться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d208>,
#  'переневерять': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d240>,
#  'сильный': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d278>,
#  'мастер': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d2b0>,
#  'немедленно': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d2e8>,
#  'заползщий': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d320>,
#  'ухо': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d358>,
#  'муравей': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d390>,
#  'нравиться': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d3c8>,
#  'фламенко': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d400>,
#  'классика': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d438>,
#  'джаз': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d470>,
#  'вдвоем': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d4a8>,
#  'сцена': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d4e0>,
#  'лагерь': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d518>,
#  'мусор': <gensim.models.keyedvectors.Vocab at 0x7ff4b987d550>}

# %%
model.wv.most_similar('жена')
# Out:
# [('пи', 0.37423408031463623),
#  ('лететь', 0.3694954216480255),
#  ('за', 0.36729681491851807),
#  ('ти', 0.3627749979496002),
#  ('а', 0.3618308901786804),
#  ('у', 0.34864819049835205),
#  ('да', 0.345253586769104),
#  ('аз', 0.34447991847991943),
#  ('е', 0.3365049362182617),
#  ('жужжать', 0.3361744284629822)]

# %%
def search(word, model, texts, preprocessed_texts):
    mystem = pymystem3.Mystem()
    word = mystem.lemmatize(word)[0]
    print(word)
    searched_texts = set()
    for i in range(len(preprocessed_texts)):
        if word in preprocessed_texts[i]:
            searched_texts.add(texts[i])
    for result in model.wv.most_similar(word):
        similar_word = result[0]
        for i in range(len(preprocessed_texts)):
            if similar_word in preprocessed_texts[i]:
                searched_texts.add(texts[i])
    return list(searched_texts)

# %%
for text in search('любви', model, verses, preprocessed_verses):
    print(text)
    print('***')
# Out:
# любовь
#
# ища существованья смысыл
# внутри себя любовь ища
# пойми что счастье ведь не завтра
# а ща
#
#
# ***
#
# олег женился на себе же
# и все завидуют ему
# ведь по любви не по залету
# и муж прекрасный человек
#
#
#
# ***
# ОН
#
# Эх, поморна
# Лебедна.
# Ты меерна,
# Да бабна.
# Вот колючин
# Не застричь.
# Он похучен,
# Да пиич.
#
#
#
#
# ***
# ПОЭТ
#
# ю
# ра
# мил
# о
# ра
# va
# и
#
# ю
# ра
# и
# ра
# о
# lа
# lа
#
# ра
# ю
# ми
# ло
# ю
# ра
# о
#
# ю
# ра
# рим
# и
# мир
# и
# ра
#
#
#
#
# ***
# ГОЛОСА
#
# — А лебеда дебела.
# — Лебеда? А! — дебил.
# Да, да, да: Ад.
# — Пирог — о, день,
# Не догори!
# О, день,
# Не до...
# — Дали — Дали!
# Либо — Ли Бо!
# Дали...
# — Боль, стыд, страх, ртс, смрад, ГОССТРАХ.
# — Икар!
# — Раки.
# — 1, 3, 5, 9, 10, 33, 100, 1985.
#
#
#
#
# ***
# ИГРА
#
# а вокзал Глазкова
# тет-а-тет
# а вон снова
# вони бред
# колокола около
# руж ажур
# кока-кола броколли
# рюс и сюр
# и нема в помине
# тел и лет
# я ныне ныне ныне
# дед
#
#
#
#
# ***
# семен успел на электричку
# и там ему сломали нос
# и он сидит понять не может
# так он везучий или нет
#
#
# ***
#
# стилистика кельи
# квартира корабль
# летящий
# во сне ноосферы
# зангези зау
# за у
# за уу
# крен вирус и визги
# скр ты
# скрыбыр ты
# удары словами поддых
# и не словами
# день-
# ги
# щипящее иго
# боль и больница
# реанимация
# мамочка мама не умирай
# папа держись
# мама и папа не уходите
# не уходите
# не уходите
# возьмите мои силы
# сан ра
# дети ра
# прана
#
#
#
#
#
#
# ***
#
# будите всех я обосрался
# и жрать хочу аж не могу
# орал олег а получалось
# агу
#
#
# ***
# ДИВО
#
# Летел лебедь дебел.
# Летел, как SOS!
# А жужжа:
# «Шабаш,
# Полк,
# Как клоп,
# Аз за Аза,
# Но Коза N.
# А мама
# Ведь Дева!»
# Летел лебедь дебел.
# А жужжа!
# Не — «па-па-па
# пи-пи-пи
# ти-ти-ти»,
# Не — «дыр, бул, щыл,
# убещур
# скум
# вы со бу
# р л эз».
# А — «Tercum non datur,
# Chacun fait son choix!»
# Не — «хррр! урарь! хор!
# кухарка!..»
# А — «с пс ст тс ш щ ж з».
# А жужжа!
# Летел лебедь дебел.
#
#
#
#
# ***
#
# не шол не спал не ел не какал
# но вовсе не из за любви
# не шол не спал из за футбола
# не какал из за что не ел
#
#
#
# ***
#
# секс не бывает безопасным
# вздохнул мужчина с топором
# однако и отказ от секса
# вам может сильно навредить
#
#
#
# ***
# И
#
# или
# ии
# лии
# ли
#
# или
# лии
# ии
# ли
#
# ии
# лии
# или
# и
#
#
#
#
# ***
# ДЕНЬГИ
#
# у.е.
# у.ё.
# а руб.
# за бур-
# ел
# у.е.
# съел
# у.е.
# у ле
# а ле
# о е
# е-е!
#
#
#
#
# ***
# НОВ
#
# нов
# и
# тон
# ха
# ха
# ах
# ах
#
# жен
# я
# ха
# рит
# о
# но
# въ
#
# тир
# о
# неж
# и
# ра
# и
# раж
#
#
#
#
# ***
#
# Я села, Олеся,
# мо... да с адом
# тет-а-тет.
# Цена: танец
# тенет.
# Я... но могу, угомоня
# ок темь метко...
# О, лежать тяжело.
# О, дух, худо
# ей, ей-ей.
# Там, там — мат, мат,
# татам,
# шум, гам (е) — не маг — му (ш).
# Олеся — село!
# Город дорог?
# Э-не.
# Град — гад. Даг — дарг.
# когда захочется чего то
# вот так что вынь прям да положь
# я сразу так и поступаю
# я вынимаю и кладу
#
#
#
# ***
#
# я вас любил подумал пушкин
# включил планшет открыл блокнот
# любил любовь ещё быть может
# загуглил вроде не боян
#
#
# ***
#
# что может быть сильнее страсти
# спросил у мастера олег
# и тот немедленно ответил
# заползщий в ухо муравей
#
#
# ***
#
# заумь
# завымь
# zoom
# безумь
#
# зумь
# безумь
# тамбовь
# любовь
#
# зы керзы
# керзы и зы
# эза рцы
# и гы гы гы
#
# графоман
# не графоман
# граф о манн
# геруф гарун
#
# эзра
# бездна
# ро
# добро
#
#
#
#
#
# ***
#
# я современное искусство
# не понимаю потому
# что там все сложно и такое
# я сам могу нарисовать
#
#
#
# ***
#
#
# марина дмитриевна про
# и пра и кро
# аз буки веди и добро
# листок перо
#
# евгений викторович сте
# и степь и стыд
# и разрушитель ватных стен
# и вечный жид
#
# а жизнь устроена хитро
# добро добро
# и зло и злоба и добро
# листок перо
#
#
#
#
# ***
#
# плоть
# путь
# плот
# плыть
#
# плоть
# пыл
# плоть
# жар
#
# плоть
# гроб
# прах
# дух
#
# дух
# путь
# дух
# путь
#
#
#
#
# ***
#
# пылеу
# зылеу
# ылеу
# уле
#
# а грынга
# горынга
# зарынга
# зары
#
# не зу
# не зу-зу
# курасу
# курасу
#
#
#
#
# ***
#
# поэт не может быть счастливым
# тогда он сразу не поэт
# и он от этого несчастен
# и снова он поэт тогда
#
#
# ***
