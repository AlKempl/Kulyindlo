# %%
import gensim
import re
import unicodedata
import pymystem3

# %%
f = open('stop_words.txt', 'r')
stop_words = []
for line in f:
    stop_words.append(line.strip())
print(len(stop_words))
print(stop_words)
# Out:
# 258
# ['а', 'без', 'более', 'бы', 'был', 'была', 'были', 'было', 'быть', 'в', 'вам', 'вас', 'весь', 'во', 'вот', 'все', 'всего', 'всех', 'вы', 'где', 'да', 'даже', 'для', 'доX', 'его', 'ее', 'если', 'есть', 'еще', 'же', 'за', 'здесь', 'и', 'из', 'или', 'им', 'их', 'к', 'как', 'ко', 'когда', 'кто', 'ли', 'либо', 'мне', 'может', 'мы', 'на', 'надо', 'наш', 'не', 'него', 'нее', 'нет', 'ни', 'них', 'но', 'ну', 'о', 'об', 'однако', 'он', 'она', 'они', 'оно', 'от', 'очень', 'по', 'под', 'при', 'с', 'со', 'так', 'также', 'такой', 'там', 'те', 'тем', 'то', 'того', 'тоже', 'той', 'только', 'том', 'ты', 'у', 'уже', 'хотя', 'чего', 'чей', 'чем', 'что', 'чтобы', 'чье', 'чья', 'эта', 'эти', 'это', 'я', 'и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'сказал', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'человек', 'чего', 'раз', 'тоже', 'себе', 'под', 'жизнь', 'будет', 'ж', 'тогда', 'кто', 'этот', 'говорил', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'кажется', 'сейчас', 'были', 'куда', 'зачем', 'сказать', 'всех', 'никогда', 'сегодня', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'сказала', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']

# %%
#f = open('verses.txt', 'r')
f = open('zaum.txt', 'r')
verses = []
preprocessed_verses = []
verse = ''
mystem = pymystem3.Mystem()
words_count = 0

for line in f:
    if line.startswith(u'*'):
        if verse != '':
            preprocessed_verse = []
            for word in mystem.analyze(verse):
                try:
                    lemma = word['analysis'][0]['lex']
                    #if not lemma in stop_words:
                    preprocessed_verse.append(lemma)
                    print(lemma)
                except:
                    continue
            if preprocessed_verse != []:
                verses.append(verse)
                preprocessed_verses.append(preprocessed_verse)
            words_count += len(preprocessed_verse)
            verse = ''
    else:
        verse += line

f = open('verses.txt', 'r')
for line in f:
    if line.startswith(u'*'):
        if verse != '':
            preprocessed_verse = []
            for word in mystem.analyze(verse):
                try:
                    lemma = word['analysis'][0]['lex']
                    if not lemma in stop_words:
                        preprocessed_verse.append(lemma)
                        print(lemma)
                except:
                    continue
            if preprocessed_verse != []:
                verses.append(verse)
                preprocessed_verses.append(preprocessed_verse)
            words_count += len(preprocessed_verse)
            verse = ''
    else:
        verse += line
print('Words count: ' + str(words_count))
# Out:
# читать
# крученыхиад
# феофан
# бук
# крученый
# звученый
# журченый
# ученый
# крученый
# реченый
# верченый
# ух
# марина
# дмитриевна
# про
# и
# пра
# и
# кро
# аз
# бук
# вести
# и
# добро
# листок
# перо
# евгений
# викторович
# сте
# и
# степь
# и
# стыд
# и
# разрушитель
# ватный
# стена
# и
# вечный
# жид
# а
# жизнь
# устраивать
# хитро
# добро
# добро
# и
# зло
# и
# злоба
# и
# добро
# листок
# перо
# заумь
# завымь
# безумить
# зумь
# безумить
# тамбовь
# любовь
# керз
# керз
# и
# эза
# рцы
# и
# графоман
# не
# графоман
# граф
# о
# манн
# геруф
# гарун
# эзра
# бездна
# ро
# добро
# поэт
# виртуоз
# курочкин
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# ко
# деньги
# у
# е
# у
# е
# а
# руб
# за
# бур
# есть
# у
# е
# съедать
# у
# е
# у
# ле
# а
# ле
# о
# е
# е
# е
# женя
# харитонов
# же
# ха
# то
# новый
# новый
# новый
# и
# тон
# ха
# ха
# ах
# ах
# жена
# я
# ха
# рита
# о
# но
# в
# тир
# о
# неж
# и
# и
# раж
# пылеу
# зылеу
# ылеу
# уля
# а
# грынга
# горынга
# зарынга
# зара
# не
# не
# курас
# курас
# поэт
# ю
# милый
# о
# и
# ю
# и
# о
# ю
# ми
# ю
# о
# ю
# рим
# и
# мир
# и
# оуэо
# эуо
# эра
# ряо
# ряо
# рэо
# ия
# гру
# меч
# кру
# ча
# он
# эх
# поморный
# лебедный
# ты
# меерный
# да
# бабный
# вот
# колючина
# не
# застригать
# он
# похучивать
# да
# пиич
# стилистика
# келья
# квартира
# корабль
# лететь
# во
# сон
# ноосфера
# зангезти
# зау
# за
# у
# за
# крен
# вирус
# и
# визг
# ты
# скрыбыр
# ты
# удар
# слово
# поддых
# и
# не
# слово
# день
# ги
# щипящий
# иго
# боль
# и
# больница
# реанимация
# мамочка
# мама
# не
# умирать
# папа
# держаться
# мама
# и
# папа
# не
# уходить
# не
# уходить
# не
# уходить
# взять
# мой
# сила
# сан
# ребенок
# прана
# он
# кобзарь
# озарь
# грандиозарь
# виртуозарь
# звень
# разом
# логос
# разум
# мрынь
# грынь
# или
# даже
# стыть
# стыть
# зау
# логос
# ребус
# женя
# шень
# вау
# логос
# мелос
# звень
# звень
# даже
# если
# это
# трень-брень
# даже
# если
# это
# дрянь
# хрень
# только
# все
# же
# это
# звень
# звень
# только
# все
# же
# это
# звень
# звень
# плоть
# путь
# плот
# плыть
# плоть
# пыл
# плоть
# жар
# плоть
# гроб
# прах
# дух
# дух
# путь
# дух
# путь
# и
# или
# ия
# лия
# ли
# или
# лия
# ия
# ли
# ия
# лия
# или
# и
# тася
# таить
# тот
# я
# я
# тот
# ты
# рот
# пьеса
# страсть
# страсть
# страсть
# страсть
# страсть
# занавес
# игра
# а
# вокзал
# глазков
# тет-а-тет
# а
# вон
# снова
# вонь
# бред
# колокол
# около
# руж
# ажур
# кока-кола
# броколли
# рюс
# и
# сюр
# и
# нема
# в
# помин
# тело
# и
# год
# я
# ныне
# ныне
# ныне
# дед
# диво
# лететь
# лебедь
# дебелый
# лететь
# как
# а
# жужжать
# шабаш
# полк
# как
# клоп
# аз
# за
# аз
# но
# коза
# а
# мама
# ведь
# дева
# лететь
# лебедь
# дебелый
# а
# жужжать
# не
# па
# па
# па
# пи
# пи
# пи
# ти
# ти
# ти
# не
# дыра
# бул
# щыл
# убещур
# скум
# вы
# со
# р
# л
# а
# не
# урарь
# хор
# кухарка
# а
# с
# ст
# ш
# щ
# ж
# з
# а
# жужжать
# лететь
# лебедь
# дебелый
# голос
# а
# лебеда
# дебелый
# лебеда
# а
# дебил
# да
# да
# да
# ад
# пирог
# о
# день
# не
# догорать
# о
# день
# не
# до
# давать
# давать
# либо
# ли
# бо
# давать
# боль
# стыд
# страх
# смрад
# госстрах
# икар
# рак
# человеческий
# жизнь
# тик
# так
# тик
# так
# тук
# тук
# тук
# тук
# садиться
# олеся
# мо
# ад
# тет-а-тет
# цена
# танец
# тенета
# мочь
# угомонить
# ока
# темь
# метко
# лежать
# тяжело
# дух
# худо
# ей-ей
# мат
# мат
# тат
# шум
# гам
# е
# маг
# му
# ш
# олеся
# село
# город
# дорогой
# э
# град
# гад
# даг
# дарг
# захотеться
# вынимать
# прямой
# полаживать
# сразу
# поступать
# вынимать
# класть
# вчера
# продавать
# душа
# черта
# причем
# выгодный
# цена
# замечать
# дефект
# гарантия
# вернуть
# короче
# главное
# улыбка
# диктор
# говорить
# кругом
# пи
# погода
# рассказывать
# николай
# малевич
# плюнуть
# чертыхнуться
# кубик
# рубик
# швырнуть
# казеть
# раскрасить
# черный
# собирать
# давно
# оксана
# жить
# успевать
# поскольку
# дело
# который
# сперва
# заканчивать
# жить
# сзади
# подходить
# прикрывать
# ладонь
# твой
# глаз
# слушать
# грустно
# виктор
# иван
# василий
# константин
# четыре
# год
# вокруг
# пятьдесят
# многу
# простой
# вещь
# приходиться
# объяснять
# встречаться
# глаз
# оба
# понимать
# необходимо
# повстречаться
# друг
# друг
# илья
# покрывать
# позор
# оказываться
# позор
# илья
# лицо
# позор
# узнавать
# губернатор
# проблема
# взять
# асфальт
# дорога
# ездить
# порше
# который
# накладной
# асфальт
# мужик
# идти
# конь
# поле
# конь
# внезапно
# говорить
# петь
# песня
# пусть
# секрет
# геннадий
# мысль
# блин
# существовать
# сантехник
# объяснять
# сын
# слово
# смысл
# поэма
# александр
# блок
# вопрос
# задание
# егэ
# вариант
# эскалибур
# двенадцать
# жопа
# карандаш
# параллельный
# прямой
# жить
# эвклидов
# мирок
# бегать
# пересекаться
# мир
# лобачевский
# тайком
# александра
# прочь
# пойти
# алтарь
# гость
# онемевать
# глядеть
# опустеть
# гроб
# шол
# спать
# какать
# вовсе
# любовь
# шол
# спать
# футбол
# какать
# расставаться
# пока
# известно
# встреча
# никто
# знать
# уничтожать
# планета
# негде
# жить
# уметь
# вещь
# юмор
# смотреть
# страшно
# бумага
# доставать
# чернила
# слеза
# подступать
# горло
# кончаться
# февраль
# современный
# искусство
# понимать
# сложно
# мочь
# нарисовать
# олег
# утренник
# школа
# глядеть
# плясать
# ребенок
# понимать
# счастие
# пора
# достаточно
# кот
# ложный
# скромность
# замечать
# гениальный
# ничто
# создавать
# занятый
# болеть
# секс
# бывать
# безопасный
# вздыхать
# мужчина
# топор
# отказ
# секс
# мочь
# сильно
# навредить
# украсть
# шапка
# мономах
# след
# шаинский
# вести
# первый
# алиби
# непрочно
# второй
# говорить
# мужчина
# слышаться
# секс
# долгий
# прямой
# какаято
# беда
# находить
# свалка
# улучшатель
# применять
# вокруг
# улучшать
# брат
# мать
# собака
# плохой
# ура
# внутри
# каждый
# космос
# значит
# каждый
# целое
# непригодный
# холодный
# пустой
# внутри
# предвидеть
# твой
# вопрос
# отвечать
# бедный
# злой
# трусливый
# слабый
# невезучий
# умный
# извинять
# нужно
# укреплять
# богема
# диктатор
# тотчас
# отборный
# тридцать
# офицер
# надевать
# шарф
# уходить
# запой
# ненавидеть
# долго
# принцип
# забывать
# почему
# ненавидеть
# собственно
# олег
# жениться
# завидовать
# любовь
# залет
# муж
# прекрасный
# море
# дорогой
# отпуск
# ехать
# гриб
# наслаждаться
# закат
# губа
# свой
# характер
# закалять
# преодоление
# преграда
# упорно
# циркуль
# рисовать
# квадрат
# входить
# дом
# пора
# осенний
# развивать
# тоска
# создавать
# семья
# обувь
# переться
# убивать
# дыхнуть
# ладонь
# украдкой
# брежнев
# разглаживать
# бровь
# вздергивать
# нос
# подумать
# чаушеска
# взасос
# искать
# существование
# смысыл
# внутри
# любовь
# искать
# понимать
# счастие
# завтра
# ща
# будить
# обсираться
# жрать
# хотеть
# аж
# мочь
# орать
# олег
# получаться
# ага
# здаров
# писать
# лор
# справка
# здаров
# писать
# ортопед
# хирург
# фсема
# чмок
# чят
# превед
# матроскин
# твой
# хозяин
# который
# объездить
# мир
# называть
# обычно
# мессир
# пусть
# карл
# клара
# постареть
# пронести
# сквозь
# год
# страсть
# смотреть
# друг
# друг
# украсть
# рубашка
# гладить
# шуба
# просить
# башка
# пелевин
# плутарх
# родной
# просто
# ангел
# арх
# боб
# марля
# таня
# высылать
# мячик
# обратно
# краснодарский
# край
# пометка
# вылавливать
# приходить
# бетховен
# почта
# странный
# коробок
# письмо
# дарить
# нужный
# ван
# гог
# подряд
# спасать
# становиться
# кричать
# рассердить
# мазай
# ежик
# пингвин
# зайя
# тошнить
# грамотей
# лицемерие
# ложь
# класть
# кафель
# ложа
# искать
# козерог
# попадаться
# овен
# причем
# овно
# морг
# прохладный
# чистый
# уют
# портить
# практикант
# блевать
# ненавидеть
# твой
# тэ
# девять
# писать
# любить
# писать
# выходить
# деньги
# сука
# слать
# ворона
# вместо
# сыр
# господь
# посылать
# тирамис
# озадачивать
# лиса
# мяч
# резиновый
# эскадра
# нестись
# гонимый
# нева
# страшный
# облик
# таня
# вой
# лежать
# маленький
# коли
# карман
# тридцать
# желудь
# богато
# свет
# воспринимать
# равный
# существо
# настолько
# сука
# превосходить
# статья
# самый
# минута
# бог
# смотреть
# пристально
# думать
# сначала
# тапок
# сначала
# дихлофос
# поэт
# мочь
# счастливый
# сразу
# поэт
# несчастный
# снова
# поэт
# жить
# хлеб
# непомыть
# плита
# спрашивать
# андрей
# сразу
# умирать
# крайний
# мера
# купить
# диван
# купить
# продукт
# купить
# киоск
# сигарета
# купить
# бухнуть
# приходить
# квартира
# сидеть
# курить
# бухать
# олег
# маньяк
# татуировщик
# уклон
# национализм
# татуировать
# нерусский
# палех
# гжель
# хохлома
# мужчина
# вовсе
# загадка
# суть
# простой
# пирожок
# пирожок
# штука
# объяснять
# рыдать
# кровавый
# слеза
# выходить
# замуж
# петр
# приходить
# ночь
# эсэмэск
# што
# петр
# олег
# хотеть
# жить
# ижевск
# милый
# сэн
# тропэ
# зарплата
# ехать
# туда
# двадцать
# пять
# секунда
# последний
# идиот
# тридцать
# год
# стоять
# хвост
# постепенно
# продвигаться
# первый
# идиот
# хотеть
# становиться
# пророк
# гибель
# предрекать
# б
# верить
# смеяться
# говорить
# рано
# думать
# становиться
# взрослый
# далее
# проходить
# становиться
# взрослый
# семен
# успевать
# электричка
# сломать
# нос
# сидеть
# понимать
# мочь
# везучий
# утро
# ехать
# работа
# работа
# снова
# ехать
# работа
# поскольку
# следующий
# день
# увы
# раб
# свой
# желание
# подневольный
# хотеть
# еда
# приходиться
# покушать
# хотеть
# поспать
# приходиться
# поспать
# слово
# хуй
# галерка
# вставать
# партер
# попрятать
# веер
# замирать
# игорь
# гобой
# ужас
# нагнетать
# фотоаппарат
# кончаться
# заряд
# обязательно
# навстречу
# бежать
# нудистка
# лось
# катиться
# колобок
# лес
# петь
# песня
# уходить
# дело
# замечать
# рот
# проехать
# гавно
# любить
# подумать
# пушкин
# включать
# планшет
# открывать
# блокнот
# любить
# любовь
# мочь
# загуглить
# вроде
# боян
# сходиться
# фома
# станиславский
# друг
# против
# друг
# становиться
# рост
# олимпиец
# состязаться
# переневерять
# мочь
# сильный
# страсть
# спрашивать
# мастер
# олег
# немедленно
# отвечать
# заползщий
# ухо
# муравей
# оксана
# нравиться
# фламенко
# олег
# классика
# джаз
# вдвоем
# сцена
# петь
# лагерь
# мусор
# Words count: 1257

# %%
model = gensim.models.Word2Vec(preprocessed_verses, size=150, window=15, min_count=1)
model.train(preprocessed_verses, total_examples=len(verses), epochs=15)
# Out:
# (17066, 18855)

# %%
len(model.wv.vocab)
# Out:
# 843

# %%
model.wv.vocab
# Out:
# {'читать': <gensim.models.keyedvectors.Vocab at 0x7f63e7fe59b0>,
#  'крученыхиад': <gensim.models.keyedvectors.Vocab at 0x7f63e7fe56a0>,
#  'феофан': <gensim.models.keyedvectors.Vocab at 0x7f63e7fe5e48>,
#  'бук': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbcc0>,
#  'крученый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb470>,
#  'звученый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbf60>,
#  'журченый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbda0>,
#  'ученый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb908>,
#  'реченый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbdd8>,
#  'верченый': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbeb8>,
#  'ух': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb748>,
#  'марина': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcba58>,
#  'дмитриевна': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb898>,
#  'про': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb5f8>,
#  'и': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb550>,
#  'пра': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbcf8>,
#  'кро': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbd30>,
#  'аз': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb668>,
#  'вести': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbbe0>,
#  'добро': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb860>,
#  'листок': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbac8>,
#  'перо': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbd68>,
#  'евгений': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb438>,
#  'викторович': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcba20>,
#  'сте': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb828>,
#  'степь': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb978>,
#  'стыд': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb9e8>,
#  'разрушитель': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbe48>,
#  'ватный': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcb6a0>,
#  'стена': <gensim.models.keyedvectors.Vocab at 0x7f63e7fcbe80>,
#  'вечный': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda7f0>,
#  'жид': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda438>,
#  'а': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda7b8>,
#  'жизнь': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda4e0>,
#  'устраивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda780>,
#  'хитро': <gensim.models.keyedvectors.Vocab at 0x7f63e7fda4a8>,
#  'зло': <gensim.models.keyedvectors.Vocab at 0x7f63e7fdaba8>,
#  'злоба': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcc88>,
#  'заумь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffca20>,
#  'завымь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc080>,
#  'безумить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcba8>,
#  'зумь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcac8>,
#  'тамбовь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcc18>,
#  'любовь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcbe0>,
#  'керз': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc1d0>,
#  'эза': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffca58>,
#  'рцы': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcd30>,
#  'графоман': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc4a8>,
#  'не': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc438>,
#  'граф': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc128>,
#  'о': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcd68>,
#  'манн': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc6d8>,
#  'геруф': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc240>,
#  'гарун': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffceb8>,
#  'эзра': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc860>,
#  'бездна': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc978>,
#  'ро': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc0f0>,
#  'поэт': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffcfd0>,
#  'виртуоз': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc208>,
#  'курочкин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc390>,
#  'ко': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffc048>,
#  'деньги': <gensim.models.keyedvectors.Vocab at 0x7f63e7ffccf8>,
#  'у': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8ecf8>,
#  'е': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8eeb8>,
#  'руб': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8e4a8>,
#  'за': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8e470>,
#  'бур': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8ec18>,
#  'есть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8ee80>,
#  'съедать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8eb70>,
#  'ле': <gensim.models.keyedvectors.Vocab at 0x7f63e7f8e400>,
#  'женя': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4908>,
#  'харитонов': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4898>,
#  'же': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4860>,
#  'ха': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4828>,
#  'то': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed47f0>,
#  'новый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed47b8>,
#  'тон': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4780>,
#  'ах': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4748>,
#  'жена': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4710>,
#  'я': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed46d8>,
#  'рита': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed46a0>,
#  'но': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4668>,
#  'в': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4630>,
#  'тир': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed45f8>,
#  'неж': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed45c0>,
#  'раж': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4588>,
#  'пылеу': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4550>,
#  'зылеу': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4518>,
#  'ылеу': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed44e0>,
#  'уля': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed44a8>,
#  'грынга': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4470>,
#  'горынга': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4438>,
#  'зарынга': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4400>,
#  'зара': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed43c8>,
#  'курас': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4390>,
#  'ю': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4358>,
#  'милый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4320>,
#  'ми': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed42e8>,
#  'рим': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed42b0>,
#  'мир': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4278>,
#  'оуэо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4240>,
#  'эуо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4208>,
#  'эра': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed41d0>,
#  'ряо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4198>,
#  'рэо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4160>,
#  'ия': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4128>,
#  'гру': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed40f0>,
#  'меч': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed40b8>,
#  'кру': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4080>,
#  'ча': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4048>,
#  'он': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed4940>,
#  'эх': <gensim.models.keyedvectors.Vocab at 0x7f63e7fc2550>,
#  'поморный': <gensim.models.keyedvectors.Vocab at 0x7f63e7e844e0>,
#  'лебедный': <gensim.models.keyedvectors.Vocab at 0x7f63e7e845c0>,
#  'ты': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84470>,
#  'меерный': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84588>,
#  'да': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84550>,
#  'бабный': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84518>,
#  'вот': <gensim.models.keyedvectors.Vocab at 0x7f63e7e847f0>,
#  'колючина': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84828>,
#  'застригать': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84860>,
#  'похучивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7e845f8>,
#  'пиич': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84630>,
#  'стилистика': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84668>,
#  'келья': <gensim.models.keyedvectors.Vocab at 0x7f63e7e846a0>,
#  'квартира': <gensim.models.keyedvectors.Vocab at 0x7f63e7e846d8>,
#  'корабль': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84710>,
#  'лететь': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84748>,
#  'во': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84780>,
#  'сон': <gensim.models.keyedvectors.Vocab at 0x7f63e7e847b8>,
#  'ноосфера': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84898>,
#  'зангезти': <gensim.models.keyedvectors.Vocab at 0x7f63e7e848d0>,
#  'зау': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84908>,
#  'крен': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84940>,
#  'вирус': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84978>,
#  'визг': <gensim.models.keyedvectors.Vocab at 0x7f63e7e849b0>,
#  'скрыбыр': <gensim.models.keyedvectors.Vocab at 0x7f63e7e849e8>,
#  'удар': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84a20>,
#  'слово': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84a58>,
#  'поддых': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84a90>,
#  'день': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84ac8>,
#  'ги': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84b00>,
#  'щипящий': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84b38>,
#  'иго': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84b70>,
#  'боль': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84ba8>,
#  'больница': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84be0>,
#  'реанимация': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84c18>,
#  'мамочка': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84c50>,
#  'мама': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84c88>,
#  'умирать': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84cc0>,
#  'папа': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84cf8>,
#  'держаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84d30>,
#  'уходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84d68>,
#  'взять': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84da0>,
#  'мой': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84dd8>,
#  'сила': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84e10>,
#  'сан': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84e48>,
#  'ребенок': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84e80>,
#  'прана': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84eb8>,
#  'кобзарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84ef0>,
#  'озарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84f28>,
#  'грандиозарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84f60>,
#  'виртуозарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84f98>,
#  'звень': <gensim.models.keyedvectors.Vocab at 0x7f63e7e84fd0>,
#  'разом': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c048>,
#  'логос': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c080>,
#  'разум': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c0b8>,
#  'мрынь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c0f0>,
#  'грынь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c128>,
#  'или': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c160>,
#  'даже': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c198>,
#  'стыть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c1d0>,
#  'ребус': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c208>,
#  'шень': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c240>,
#  'вау': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c278>,
#  'мелос': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c2b0>,
#  'если': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c2e8>,
#  'это': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c320>,
#  'трень-брень': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c358>,
#  'дрянь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c390>,
#  'хрень': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c3c8>,
#  'только': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c400>,
#  'все': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c438>,
#  'плоть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c470>,
#  'путь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c4a8>,
#  'плот': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c4e0>,
#  'плыть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c518>,
#  'пыл': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c550>,
#  'жар': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c588>,
#  'гроб': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c5c0>,
#  'прах': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c5f8>,
#  'дух': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c630>,
#  'лия': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c668>,
#  'ли': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c6a0>,
#  'тася': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c6d8>,
#  'таить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c710>,
#  'тот': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c748>,
#  'рот': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c780>,
#  'пьеса': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c7b8>,
#  'страсть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c7f0>,
#  'занавес': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c828>,
#  'игра': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c860>,
#  'вокзал': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c898>,
#  'глазков': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c8d0>,
#  'тет-а-тет': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c908>,
#  'вон': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c940>,
#  'снова': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c978>,
#  'вонь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c9b0>,
#  'бред': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4c9e8>,
#  'колокол': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ca20>,
#  'около': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ca58>,
#  'руж': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ca90>,
#  'ажур': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cac8>,
#  'кока-кола': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cb00>,
#  'броколли': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cb38>,
#  'рюс': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cb70>,
#  'сюр': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cba8>,
#  'нема': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cbe0>,
#  'помин': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cc18>,
#  'тело': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cc50>,
#  'год': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cc88>,
#  'ныне': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ccc0>,
#  'дед': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ccf8>,
#  'диво': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cd30>,
#  'лебедь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cd68>,
#  'дебелый': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cda0>,
#  'как': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cdd8>,
#  'жужжать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ce10>,
#  'шабаш': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ce48>,
#  'полк': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ce80>,
#  'клоп': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4ceb8>,
#  'коза': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cef0>,
#  'ведь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cf28>,
#  'дева': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cf60>,
#  'па': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cf98>,
#  'пи': <gensim.models.keyedvectors.Vocab at 0x7f63e7f4cfd0>,
#  'ти': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67048>,
#  'дыра': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67080>,
#  'бул': <gensim.models.keyedvectors.Vocab at 0x7f63e7f670b8>,
#  'щыл': <gensim.models.keyedvectors.Vocab at 0x7f63e7f670f0>,
#  'убещур': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67128>,
#  'скум': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67160>,
#  'вы': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67198>,
#  'со': <gensim.models.keyedvectors.Vocab at 0x7f63e7f671d0>,
#  'р': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67208>,
#  'л': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67240>,
#  'урарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67278>,
#  'хор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f672b0>,
#  'кухарка': <gensim.models.keyedvectors.Vocab at 0x7f63e7f672e8>,
#  'с': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67320>,
#  'ст': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67358>,
#  'ш': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67390>,
#  'щ': <gensim.models.keyedvectors.Vocab at 0x7f63e7f673c8>,
#  'ж': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67400>,
#  'з': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67438>,
#  'голос': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67470>,
#  'лебеда': <gensim.models.keyedvectors.Vocab at 0x7f63e7f674a8>,
#  'дебил': <gensim.models.keyedvectors.Vocab at 0x7f63e7f674e0>,
#  'ад': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67518>,
#  'пирог': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67550>,
#  'догорать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67588>,
#  'до': <gensim.models.keyedvectors.Vocab at 0x7f63e7f675c0>,
#  'давать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f675f8>,
#  'либо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67630>,
#  'бо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67668>,
#  'страх': <gensim.models.keyedvectors.Vocab at 0x7f63e7f676a0>,
#  'смрад': <gensim.models.keyedvectors.Vocab at 0x7f63e7f676d8>,
#  'госстрах': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67710>,
#  'икар': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67748>,
#  'рак': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67780>,
#  'человеческий': <gensim.models.keyedvectors.Vocab at 0x7f63e7f677b8>,
#  'тик': <gensim.models.keyedvectors.Vocab at 0x7f63e7f677f0>,
#  'так': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67828>,
#  'тук': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67860>,
#  'садиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67898>,
#  'олеся': <gensim.models.keyedvectors.Vocab at 0x7f63e7f678d0>,
#  'мо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67908>,
#  'цена': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67940>,
#  'танец': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67978>,
#  'тенета': <gensim.models.keyedvectors.Vocab at 0x7f63e7f679b0>,
#  'мочь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f679e8>,
#  'угомонить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67a20>,
#  'ока': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67a58>,
#  'темь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67a90>,
#  'метко': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67ac8>,
#  'лежать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67b00>,
#  'тяжело': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67b38>,
#  'худо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67b70>,
#  'ей-ей': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67ba8>,
#  'мат': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67be0>,
#  'тат': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67c18>,
#  'шум': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67c50>,
#  'гам': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67c88>,
#  'маг': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67cc0>,
#  'му': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67cf8>,
#  'село': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67d30>,
#  'город': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67d68>,
#  'дорогой': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67da0>,
#  'э': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67dd8>,
#  'град': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67e10>,
#  'гад': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67e48>,
#  'даг': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67e80>,
#  'дарг': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67eb8>,
#  'захотеться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67ef0>,
#  'вынимать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67f28>,
#  'прямой': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67f60>,
#  'полаживать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67f98>,
#  'сразу': <gensim.models.keyedvectors.Vocab at 0x7f63e7f67fd0>,
#  'поступать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e048>,
#  'класть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e080>,
#  'вчера': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e0b8>,
#  'продавать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e0f0>,
#  'душа': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e128>,
#  'черта': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e160>,
#  'причем': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e198>,
#  'выгодный': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e1d0>,
#  'замечать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e208>,
#  'дефект': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e240>,
#  'гарантия': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e278>,
#  'вернуть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e2b0>,
#  'короче': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e2e8>,
#  'главное': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e320>,
#  'улыбка': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e358>,
#  'диктор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e390>,
#  'говорить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e3c8>,
#  'кругом': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e400>,
#  'погода': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e438>,
#  'рассказывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e470>,
#  'николай': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e4a8>,
#  'малевич': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e4e0>,
#  'плюнуть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e518>,
#  'чертыхнуться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e550>,
#  'кубик': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e588>,
#  'рубик': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e5c0>,
#  'швырнуть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e5f8>,
#  'казеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e630>,
#  'раскрасить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e668>,
#  'черный': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e6a0>,
#  'собирать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e6d8>,
#  'давно': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e710>,
#  'оксана': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e748>,
#  'жить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e780>,
#  'успевать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e7b8>,
#  'поскольку': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e7f0>,
#  'дело': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e828>,
#  'который': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e860>,
#  'сперва': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e898>,
#  'заканчивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e8d0>,
#  'сзади': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e908>,
#  'подходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e940>,
#  'прикрывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e978>,
#  'ладонь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e9b0>,
#  'твой': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3e9e8>,
#  'глаз': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ea20>,
#  'слушать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ea58>,
#  'грустно': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ea90>,
#  'виктор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eac8>,
#  'иван': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eb00>,
#  'василий': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eb38>,
#  'константин': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eb70>,
#  'четыре': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eba8>,
#  'вокруг': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ebe0>,
#  'пятьдесят': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ec18>,
#  'многу': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ec50>,
#  'простой': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ec88>,
#  'вещь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ecc0>,
#  'приходиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ecf8>,
#  'объяснять': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ed30>,
#  'встречаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ed68>,
#  'оба': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eda0>,
#  'понимать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3edd8>,
#  'необходимо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ee10>,
#  'повстречаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ee48>,
#  'друг': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ee80>,
#  'илья': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eeb8>,
#  'покрывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3eef0>,
#  'позор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ef28>,
#  'оказываться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ef60>,
#  'лицо': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ef98>,
#  'узнавать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3efd0>,
#  'губернатор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c048>,
#  'проблема': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c080>,
#  'асфальт': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c0b8>,
#  'дорога': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c0f0>,
#  'ездить': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c128>,
#  'порше': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c160>,
#  'накладной': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c198>,
#  'мужик': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c1d0>,
#  'идти': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c208>,
#  'конь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c240>,
#  'поле': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c278>,
#  'внезапно': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c2b0>,
#  'петь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c2e8>,
#  'песня': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c320>,
#  'пусть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c358>,
#  'секрет': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c390>,
#  'геннадий': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c3c8>,
#  'мысль': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c400>,
#  'блин': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c438>,
#  'существовать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c470>,
#  'сантехник': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c4a8>,
#  'сын': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c4e0>,
#  'смысл': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c518>,
#  'поэма': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c550>,
#  'александр': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c588>,
#  'блок': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c5c0>,
#  'вопрос': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c5f8>,
#  'задание': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c630>,
#  'егэ': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c668>,
#  'вариант': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c6a0>,
#  'эскалибур': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c6d8>,
#  'двенадцать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c710>,
#  'жопа': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c748>,
#  'карандаш': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c780>,
#  'параллельный': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c7b8>,
#  'эвклидов': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c7f0>,
#  'мирок': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c828>,
#  'бегать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c860>,
#  'пересекаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c898>,
#  'лобачевский': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c8d0>,
#  'тайком': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c908>,
#  'александра': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c940>,
#  'прочь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c978>,
#  'пойти': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c9b0>,
#  'алтарь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3c9e8>,
#  'гость': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ca20>,
#  'онемевать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ca58>,
#  'глядеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ca90>,
#  'опустеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cac8>,
#  'шол': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cb00>,
#  'спать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cb38>,
#  'какать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cb70>,
#  'вовсе': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cba8>,
#  'футбол': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cbe0>,
#  'расставаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cc18>,
#  'пока': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cc50>,
#  'известно': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cc88>,
#  'встреча': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ccc0>,
#  'никто': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ccf8>,
#  'знать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cd30>,
#  'уничтожать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cd68>,
#  'планета': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cda0>,
#  'негде': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cdd8>,
#  'уметь': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ce10>,
#  'юмор': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ce48>,
#  'смотреть': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ce80>,
#  'страшно': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3ceb8>,
#  'бумага': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cef0>,
#  'доставать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cf28>,
#  'чернила': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cf60>,
#  'слеза': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cf98>,
#  'подступать': <gensim.models.keyedvectors.Vocab at 0x7f63e7f3cfd0>,
#  'горло': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2048>,
#  'кончаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2080>,
#  'февраль': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed20b8>,
#  'современный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed20f0>,
#  'искусство': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2128>,
#  'сложно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2160>,
#  'нарисовать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2198>,
#  'олег': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed21d0>,
#  'утренник': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2208>,
#  'школа': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2240>,
#  'плясать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2278>,
#  'счастие': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed22b0>,
#  'пора': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed22e8>,
#  'достаточно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2320>,
#  'кот': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2358>,
#  'ложный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2390>,
#  'скромность': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed23c8>,
#  'гениальный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2400>,
#  'ничто': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2438>,
#  'создавать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2470>,
#  'занятый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed24a8>,
#  'болеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed24e0>,
#  'секс': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2518>,
#  'бывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2550>,
#  'безопасный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2588>,
#  'вздыхать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed25c0>,
#  'мужчина': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed25f8>,
#  'топор': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2630>,
#  'отказ': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2668>,
#  'сильно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed26a0>,
#  'навредить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed26d8>,
#  'украсть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2710>,
#  'шапка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2748>,
#  'мономах': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2780>,
#  'след': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed27b8>,
#  'шаинский': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed27f0>,
#  'первый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2828>,
#  'алиби': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2860>,
#  'непрочно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2898>,
#  'второй': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed28d0>,
#  'слышаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2908>,
#  'долгий': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2940>,
#  'какаято': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2978>,
#  'беда': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed29b0>,
#  'находить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed29e8>,
#  'свалка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2a20>,
#  'улучшатель': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2a58>,
#  'применять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2a90>,
#  'улучшать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2ac8>,
#  'брат': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2b00>,
#  'мать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2b38>,
#  'собака': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2b70>,
#  'плохой': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2ba8>,
#  'ура': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2be0>,
#  'внутри': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2c18>,
#  'каждый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2c50>,
#  'космос': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2c88>,
#  'значит': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2cc0>,
#  'целое': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2cf8>,
#  'непригодный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2d30>,
#  'холодный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2d68>,
#  'пустой': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2da0>,
#  'предвидеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2dd8>,
#  'отвечать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2e10>,
#  'бедный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2e48>,
#  'злой': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2e80>,
#  'трусливый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2eb8>,
#  'слабый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2ef0>,
#  'невезучий': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2f28>,
#  'умный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2f60>,
#  'извинять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2f98>,
#  'нужно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed2fd0>,
#  'укреплять': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb048>,
#  'богема': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb080>,
#  'диктатор': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb0b8>,
#  'тотчас': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb0f0>,
#  'отборный': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb128>,
#  'тридцать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb160>,
#  'офицер': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb198>,
#  'надевать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb1d0>,
#  'шарф': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb208>,
#  'запой': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb240>,
#  'ненавидеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb278>,
#  'долго': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb2b0>,
#  'принцип': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb2e8>,
#  'забывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb320>,
#  'почему': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb358>,
#  'собственно': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb390>,
#  'жениться': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb3c8>,
#  'завидовать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb400>,
#  'залет': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb438>,
#  'муж': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb470>,
#  'прекрасный': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb4a8>,
#  'море': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb4e0>,
#  'отпуск': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb518>,
#  'ехать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb550>,
#  'гриб': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb588>,
#  'наслаждаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb5c0>,
#  'закат': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb5f8>,
#  'губа': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb630>,
#  'свой': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb668>,
#  'характер': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb6a0>,
#  'закалять': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb6d8>,
#  'преодоление': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb710>,
#  'преграда': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb748>,
#  'упорно': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb780>,
#  'циркуль': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb7b8>,
#  'рисовать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb7f0>,
#  'квадрат': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb828>,
#  'входить': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb860>,
#  'дом': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb898>,
#  'осенний': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb8d0>,
#  'развивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb908>,
#  'тоска': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb940>,
#  'семья': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb978>,
#  'обувь': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb9b0>,
#  'переться': <gensim.models.keyedvectors.Vocab at 0x7f63e7edb9e8>,
#  'убивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edba20>,
#  'дыхнуть': <gensim.models.keyedvectors.Vocab at 0x7f63e7edba58>,
#  'украдкой': <gensim.models.keyedvectors.Vocab at 0x7f63e7edba90>,
#  'брежнев': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbac8>,
#  'разглаживать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbb00>,
#  'бровь': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbb38>,
#  'вздергивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbb70>,
#  'нос': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbba8>,
#  'подумать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbbe0>,
#  'чаушеска': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbc18>,
#  'взасос': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbc50>,
#  'искать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbc88>,
#  'существование': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbcc0>,
#  'смысыл': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbcf8>,
#  'завтра': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbd30>,
#  'ща': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbd68>,
#  'будить': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbda0>,
#  'обсираться': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbdd8>,
#  'жрать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbe10>,
#  'хотеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbe48>,
#  'аж': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbe80>,
#  'орать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbeb8>,
#  'получаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbef0>,
#  'ага': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbf28>,
#  'здаров': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbf60>,
#  'писать': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbf98>,
#  'лор': <gensim.models.keyedvectors.Vocab at 0x7f63e7edbfd0>,
#  'справка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd048>,
#  'ортопед': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd080>,
#  'хирург': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd0b8>,
#  'фсема': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd0f0>,
#  'чмок': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd128>,
#  'чят': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd160>,
#  'превед': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd198>,
#  'матроскин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd1d0>,
#  'хозяин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd208>,
#  'объездить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd240>,
#  'называть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd278>,
#  'обычно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd2b0>,
#  'мессир': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd2e8>,
#  'карл': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd320>,
#  'клара': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd358>,
#  'постареть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd390>,
#  'пронести': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd3c8>,
#  'сквозь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd400>,
#  'рубашка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd438>,
#  'гладить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd470>,
#  'шуба': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd4a8>,
#  'просить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd4e0>,
#  'башка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd518>,
#  'пелевин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd550>,
#  'плутарх': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd588>,
#  'родной': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd5c0>,
#  'просто': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd5f8>,
#  'ангел': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd630>,
#  'арх': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd668>,
#  'боб': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd6a0>,
#  'марля': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd6d8>,
#  'таня': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd710>,
#  'высылать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd748>,
#  'мячик': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd780>,
#  'обратно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd7b8>,
#  'краснодарский': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd7f0>,
#  'край': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd828>,
#  'пометка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd860>,
#  'вылавливать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd898>,
#  'приходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd8d0>,
#  'бетховен': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd908>,
#  'почта': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd940>,
#  'странный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd978>,
#  'коробок': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd9b0>,
#  'письмо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecd9e8>,
#  'дарить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecda20>,
#  'нужный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecda58>,
#  'ван': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecda90>,
#  'гог': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdac8>,
#  'подряд': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdb00>,
#  'спасать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdb38>,
#  'становиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdb70>,
#  'кричать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdba8>,
#  'рассердить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdbe0>,
#  'мазай': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdc18>,
#  'ежик': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdc50>,
#  'пингвин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdc88>,
#  'зайя': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdcc0>,
#  'тошнить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdcf8>,
#  'грамотей': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdd30>,
#  'лицемерие': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdd68>,
#  'ложь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdda0>,
#  'кафель': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecddd8>,
#  'ложа': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecde10>,
#  'козерог': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecde48>,
#  'попадаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecde80>,
#  'овен': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdeb8>,
#  'овно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdef0>,
#  'морг': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdf28>,
#  'прохладный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdf60>,
#  'чистый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdf98>,
#  'уют': <gensim.models.keyedvectors.Vocab at 0x7f63e7ecdfd0>,
#  'портить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9048>,
#  'практикант': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9080>,
#  'блевать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec90b8>,
#  'тэ': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec90f0>,
#  'девять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9128>,
#  'любить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9160>,
#  'выходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9198>,
#  'сука': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec91d0>,
#  'слать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9208>,
#  'ворона': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9240>,
#  'вместо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9278>,
#  'сыр': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec92b0>,
#  'господь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec92e8>,
#  'посылать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9320>,
#  'тирамис': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9358>,
#  'озадачивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9390>,
#  'лиса': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec93c8>,
#  'мяч': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9400>,
#  'резиновый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9438>,
#  'эскадра': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9470>,
#  'нестись': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec94a8>,
#  'гонимый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec94e0>,
#  'нева': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9518>,
#  'страшный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9550>,
#  'облик': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9588>,
#  'вой': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec95c0>,
#  'маленький': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec95f8>,
#  'коли': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9630>,
#  'карман': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9668>,
#  'желудь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec96a0>,
#  'богато': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec96d8>,
#  'свет': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9710>,
#  'воспринимать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9748>,
#  'равный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9780>,
#  'существо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec97b8>,
#  'настолько': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec97f0>,
#  'превосходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9828>,
#  'статья': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9860>,
#  'самый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9898>,
#  'минута': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec98d0>,
#  'бог': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9908>,
#  'пристально': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9940>,
#  'думать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9978>,
#  'сначала': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec99b0>,
#  'тапок': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec99e8>,
#  'дихлофос': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9a20>,
#  'счастливый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9a58>,
#  'несчастный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9a90>,
#  'хлеб': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9ac8>,
#  'непомыть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9b00>,
#  'плита': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9b38>,
#  'спрашивать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9b70>,
#  'андрей': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9ba8>,
#  'крайний': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9be0>,
#  'мера': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9c18>,
#  'купить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9c50>,
#  'диван': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9c88>,
#  'продукт': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9cc0>,
#  'киоск': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9cf8>,
#  'сигарета': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9d30>,
#  'бухнуть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9d68>,
#  'сидеть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9da0>,
#  'курить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9dd8>,
#  'бухать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9e10>,
#  'маньяк': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9e48>,
#  'татуировщик': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9e80>,
#  'уклон': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9eb8>,
#  'национализм': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9ef0>,
#  'татуировать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9f28>,
#  'нерусский': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9f60>,
#  'палех': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9f98>,
#  'гжель': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec9fd0>,
#  'хохлома': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5048>,
#  'загадка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5080>,
#  'суть': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec50b8>,
#  'пирожок': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec50f0>,
#  'штука': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5128>,
#  'рыдать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5160>,
#  'кровавый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5198>,
#  'замуж': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec51d0>,
#  'петр': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5208>,
#  'ночь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5240>,
#  'эсэмэск': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5278>,
#  'што': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec52b0>,
#  'ижевск': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec52e8>,
#  'сэн': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5320>,
#  'тропэ': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5358>,
#  'зарплата': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5390>,
#  'туда': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec53c8>,
#  'двадцать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5400>,
#  'пять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5438>,
#  'секунда': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5470>,
#  'последний': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec54a8>,
#  'идиот': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5550>,
#  'стоять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5588>,
#  'хвост': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec55c0>,
#  'постепенно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec55f8>,
#  'продвигаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5630>,
#  'пророк': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5668>,
#  'гибель': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec56a0>,
#  'предрекать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec56d8>,
#  'б': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5710>,
#  'верить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5748>,
#  'смеяться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5780>,
#  'рано': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec57b8>,
#  'взрослый': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec57f0>,
#  'далее': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5828>,
#  'проходить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5860>,
#  'семен': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5898>,
#  'электричка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec58d0>,
#  'сломать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5908>,
#  'везучий': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5940>,
#  'утро': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5978>,
#  'работа': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec59b0>,
#  'следующий': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec59e8>,
#  'увы': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5a20>,
#  'раб': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5a58>,
#  'желание': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5a90>,
#  'подневольный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5ac8>,
#  'еда': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5b00>,
#  'покушать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5b38>,
#  'поспать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5b70>,
#  'хуй': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5ba8>,
#  'галерка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5be0>,
#  'вставать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5c18>,
#  'партер': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5c50>,
#  'попрятать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5c88>,
#  'веер': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5cc0>,
#  'замирать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5cf8>,
#  'игорь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5d30>,
#  'гобой': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5d68>,
#  'ужас': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5da0>,
#  'нагнетать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5dd8>,
#  'фотоаппарат': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5e10>,
#  'заряд': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5e48>,
#  'обязательно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5e80>,
#  'навстречу': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5eb8>,
#  'бежать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5ef0>,
#  'нудистка': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5f28>,
#  'лось': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5f60>,
#  'катиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5f98>,
#  'колобок': <gensim.models.keyedvectors.Vocab at 0x7f63e7ec5fd0>,
#  'лес': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9048>,
#  'проехать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9080>,
#  'гавно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed90b8>,
#  'пушкин': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed90f0>,
#  'включать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9128>,
#  'планшет': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9160>,
#  'открывать': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9198>,
#  'блокнот': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed91d0>,
#  'загуглить': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9208>,
#  'вроде': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9240>,
#  'боян': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9278>,
#  'сходиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed92b0>,
#  'фома': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed92e8>,
#  'станиславский': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9320>,
#  'против': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9358>,
#  'рост': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9390>,
#  'олимпиец': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed93c8>,
#  'состязаться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9400>,
#  'переневерять': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9438>,
#  'сильный': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9470>,
#  'мастер': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed94a8>,
#  'немедленно': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed94e0>,
#  'заползщий': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9518>,
#  'ухо': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9550>,
#  'муравей': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9588>,
#  'нравиться': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed95c0>,
#  'фламенко': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed95f8>,
#  'классика': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9630>,
#  'джаз': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9668>,
#  'вдвоем': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed96a0>,
#  'сцена': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed96d8>,
#  'лагерь': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9710>,
#  'мусор': <gensim.models.keyedvectors.Vocab at 0x7f63e7ed9748>}

# %%
model.wv.most_similar('жена')
# Out:
# [('петр', 0.3022252321243286),
#  ('здаров', 0.2925926744937897),
#  ('дрянь', 0.25620174407958984),
#  ('викторович', 0.2549053430557251),
#  ('эуо', 0.2460256963968277),
#  ('преодоление', 0.24385647475719452),
#  ('мирок', 0.24180319905281067),
#  ('сон', 0.23923222720623016),
#  ('сука', 0.23811940848827362),
#  ('дело', 0.23521359264850616)]

# %%
def search(word, model, texts, preprocessed_texts):
    mystem = pymystem3.Mystem()
    word = mystem.lemmatize(word)[0]
    print(word)
    searched_texts = set()
    for i in range(len(preprocessed_texts)):
        if word in preprocessed_texts[i]:
            searched_texts.add(texts[i])
    for result in model.wv.most_similar(word):
        similar_word = result[0]
        for i in range(len(preprocessed_texts)):
            if similar_word in preprocessed_texts[i]:
                searched_texts.add(texts[i])
    return list(searched_texts)

# %%
for text in search('любви', model, verses, preprocessed_verses):
    print(text)
    print('***')
# Out:
# любовь
# И
#
# или
# ии
# лии
# ли
#
# или
# лии
# ии
# ли
#
# ии
# лии
# или
# и
#
#
#
#
# ***
#
# стилистика кельи
# квартира корабль
# летящий
# во сне ноосферы
# зангези зау
# за у
# за уу
# крен вирус и визги
# скр ты
# скрыбыр ты
# удары словами поддых
# и не словами
# день-
# ги
# щипящее иго
# боль и больница
# реанимация
# мамочка мама не умирай
# папа держись
# мама и папа не уходите
# не уходите
# не уходите
# возьмите мои силы
# сан ра
# дети ра
# прана
#
#
#
#
#
#
# ***
#
# пылеу
# зылеу
# ылеу
# уле
#
# а грынга
# горынга
# зарынга
# зары
#
# не зу
# не зу-зу
# курасу
# курасу
#
#
#
#
# ***
#
# олег женился на себе же
# и все завидуют ему
# ведь по любви не по залету
# и муж прекрасный человек
#
#
#
# ***
# ЖЕНЯ ХАРИТОНОВЪ
#
# же
# ня
# ха
# ри
# то
# нов
#
# ***
# ОН
#
# Эх, поморна
# Лебедна.
# Ты меерна,
# Да бабна.
# Вот колючин
# Не застричь.
# Он похучен,
# Да пиич.
#
#
#
#
# ***
#
# заумь
# завымь
# zoom
# безумь
#
# зумь
# безумь
# тамбовь
# любовь
#
# зы керзы
# керзы и зы
# эза рцы
# и гы гы гы
#
# графоман
# не графоман
# граф о манн
# геруф гарун
#
# эзра
# бездна
# ро
# добро
#
#
#
#
#
# ***
#
# сошлись фома и станиславский
# друг против друга стали в рост
# как олимпийцы состязаясь
# в переневерит кто кого
#
#
# ***
#
# я вас любил подумал пушкин
# включил планшет открыл блокнот
# любил любовь ещё быть может
# загуглил вроде не боян
#
#
# ***
#
#
# марина дмитриевна про
# и пра и кро
# аз буки веди и добро
# листок перо
#
# евгений викторович сте
# и степь и стыд
# и разрушитель ватных стен
# и вечный жид
#
# а жизнь устроена хитро
# добро добро
# и зло и злоба и добро
# листок перо
#
#
#
#
# ***
#
# не шол не спал не ел не какал
# но вовсе не из за любви
# не шол не спал из за футбола
# не какал из за что не ел
#
#
#
# ***
# ПОЭТ
#
# ю
# ра
# мил
# о
# ра
# va
# и
#
# ю
# ра
# и
# ра
# о
# lа
# lа
#
# ра
# ю
# ми
# ло
# ю
# ра
# о
#
# ю
# ра
# рим
# и
# мир
# и
# ра
#
#
#
#
# ***
# ЗВЕНЬ
#
# разом: логос-разум — мрынь
# грынь
# или даже — стынь
# стынь
#
# зау! — логос-ребус — жень
# шень
# вау! — логос-мелос — звень
# звень
#
# даже если это трень-брень
# даже если это дрянь-хрень
# только все же это звень-звень
# только все же это звень-звень!
#
#
#
#
# ***
# НОВ
#
# нов
# и
# тон
# ха
# ха
# ах
# ах
#
# жен
# я
# ха
# рит
# о
# но
# въ
#
# тир
# о
# неж
# и
# ра
# и
# раж
#
#
#
#
# ***
# ДИВО
#
# Летел лебедь дебел.
# Летел, как SOS!
# А жужжа:
# «Шабаш,
# Полк,
# Как клоп,
# Аз за Аза,
# Но Коза N.
# А мама
# Ведь Дева!»
# Летел лебедь дебел.
# А жужжа!
# Не — «па-па-па
# пи-пи-пи
# ти-ти-ти»,
# Не — «дыр, бул, щыл,
# убещур
# скум
# вы со бу
# р л эз».
# А — «Tercum non datur,
# Chacun fait son choix!»
# Не — «хррр! урарь! хор!
# кухарка!..»
# А — «с пс ст тс ш щ ж з».
# А жужжа!
# Летел лебедь дебел.
#
#
#
#
# ***
# ДЕНЬГИ
#
# у.е.
# у.ё.
# а руб.
# за бур-
# ел
# у.е.
# съел
# у.е.
# у ле
# а ле
# о е
# е-е!
#
#
#
#
# ***
#
# пусть карл и клара постарели
# но пронеся сквозь годы страсть
# всё смотрят что бы друг у друга
# украсть
#
#
# ***
#
# тася
# тая
# та
# я
#
# я
# та
# ты
# рты
#
#
#
#
# ***
# ИГРА
#
# а вокзал Глазкова
# тет-а-тет
# а вон снова
# вони бред
# колокола около
# руж ажур
# кока-кола броколли
# рюс и сюр
# и нема в помине
# тел и лет
# я ныне ныне ныне
# дед
#
#
#
#
# ***
# ГОЛОСА
#
# — А лебеда дебела.
# — Лебеда? А! — дебил.
# Да, да, да: Ад.
# — Пирог — о, день,
# Не догори!
# О, день,
# Не до...
# — Дали — Дали!
# Либо — Ли Бо!
# Дали...
# — Боль, стыд, страх, ртс, смрад, ГОССТРАХ.
# — Икар!
# — Раки.
# — 1, 3, 5, 9, 10, 33, 100, 1985.
#
#
#
#
# ***
#
# когда мы встретились глазами
# мы оба поняли что нам
# необходимо повстречаться
# друг с другом чем нибудь еще
#
#
#
# ***
#
# ища существованья смысыл
# внутри себя любовь ища
# пойми что счастье ведь не завтра
# а ща
#
#
# ***
